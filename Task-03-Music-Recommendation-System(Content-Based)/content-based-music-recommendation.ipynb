# %% [markdown]
# ## `INTERN ON LetsGrowMore(LGM)`
# ## ` Beginner Level Task:`
# ### `Task no. 02 - Stock Market Prediction And Forecasting Using Stacked LSTM`
# `Dataset from url :` https://www.kaggle.com/c/kkbox-music-recommendation-challenge/data

# %% [markdown]
# <img src="task-2-3.png" />

# %% [markdown]
# # `Abstract :`
# This project focuses on techniques and tools for handling Time Series Datasets. Main aim of this project is to make Stock Market Prediction and Forecasting using Stacked LSTM.
#
# Time series data is data that is recorded over consistent intervals of time.
#
# Time Series Datasets consist of more than one attributes depending on DateTime attribute of our dataset.
#
# Long short-term memory (LSTM) is an artificial neural network used in the fields of artificial intelligence and deep learning.
#
# It is a variety of recurrent neural networks (RNNs) that are capable of learning long-term dependencies, especially in sequence prediction problems. LSTM has feedback connections, i.e., it is capable of processing the entire sequence of data, apart from single data points such as images.
#
# ### `Two approaches for solving this problem`
#
# i) Univariate Time Series Analysis : univariate time series model here means that there are only one dependent variable on the time series model
#
# ii) Multivariate Time Series Analysis: it consist of more than one time-dependent variable and each variable depends not only on its past values but also has some dependency on other variables.
#
# ### `STEPS : `
#
# 1) Importing Libraries and Loading data
#
# 2) Cleaning data and sorting data by date.
#
# 3) Applying univariate approch by selecting `Closing Price` as target variables.
#
# 4) Exploration and Analysis of Datasets.
#
# 5) Preprocessing by MinMax Scaler.
#
# 6) Preparing train and test datasets.
#
# 7) Constructing Stacked LSTM model.
#
# 8) Evaluation of Model.
#
# 9) Forecasting for future 30 days.
#
# 10) Acknowledgement and References

# %% [markdown]
# ## `Let's Dive into the project`

# %% [markdown]
# ## `Step-1:` Importing required important libraries and loading dataset...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###  DATASETS
#
# Detailed Descriptions of Datasets: https://www.kaggle.com/c/kkbox-music-recommendation-challenge/data
#
# `train.csv`
# a) msno: user id

# %%
train_df = pd.read_csv("train.csv", nrows=20000) # Considering only Twenty Thousands tuples for our dataset.
train_df.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target
# 0              Explore  online-playlist       1
# 1  Local playlist more   local-playlist       1
# 2  Local playlist more   local-playlist       1
# 3  Local playlist more   local-playlist       1
# 4              Explore  online-playlist       1

# %%
song_df = pd.read_csv("songs.csv", nrows=20000)
song_df.head()
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329       726
#
#         artist_name                            composer     lyricist  language
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘       3.0
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY      31.0
# 2      SUPER JUNIOR                                 NaN          NaN      31.0
# 3             S.H.E                                 湯小康          徐世珍       3.0
# 4              貴族精選                         Traditional  Traditional      52.0

# %%
song_extra_info_df = pd.read_csv("song_extra_info.csv")
song_extra_info_df.head()
# Out:
#                                         song_id             name          isrc
# 0  LP7pLJoJFBvyuUwvu+oLzjT+bI+UeBPURCecJsX1jjs=               我們  TWUM71200043
# 1  ClazTFnk6r0Bnuie44bocdNMM3rdlrq0bCGAsGUWcHE=  Let Me Love You  QMZSY1600015
# 2  u2ja/bZE3zhCGxvbbOB3zOoUjx27u40cf5g09UXMoKQ=              原諒我  TWA530887303
# 3  92Fqsy0+p6+RHe2EoLKjHahORHR1Kq1TBJoClW9v+Ts=          Classic  USSM11301446
# 4  0QFmz/+rJy1Q56C1DuYqT9hKKqi5TUqx0sN0IwvoHrw=             愛投羅網  TWA471306001

# %% [markdown]
# ## `Step-2:` Exploratory Data Analysis (EDA) & Visualization

# %%
# Checking for null values...
train_df.isna().sum()
# Out:
# msno                    0
# song_id                 0
# source_system_tab      67
# source_screen_name    576
# source_type            50
# target                  0
# dtype: int64

# %% [markdown]
# We are only using `msno` and `song_id` attribute of this table, and these attributes dont have any `missing values`

# %%
song_df.isna().sum()
# Out:
# song_id            0
# song_length        0
# genre_ids        346
# artist_name        0
# composer        8382
# lyricist       14332
# language           0
# dtype: int64

# %% [markdown]
# We will use all attributes columns except `song_length` and `language`.
# For this, we will handle in Preprocessing steps.

# %%
song_extra_info_df.isna().sum()
# Out:
# song_id         0
# name            2
# isrc       136548
# dtype: int64

# %%
song_extra_info_df['name'] = song_extra_info_df['name'].dropna(axis=0)
song_extra_info_df['name'].isna().sum()
# Out:
# 2

# %%
song_extra_info_df.isna().sum()
# Out:
# song_id         0
# name            2
# isrc       136548
# dtype: int64

# %% [markdown]
# We will only use `song_id` and `name`. So, removing NaNs or Missing Values from that columns.

# %%
# Let's see shape,dtypes and info of dataset...

# %%
train_df.shape
# Out:
# (20000, 6)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   msno                20000 non-null  object
#  1   song_id             20000 non-null  object
#  2   source_system_tab   19933 non-null  object
#  3   source_screen_name  19424 non-null  object
#  4   source_type         19950 non-null  object
#  5   target              20000 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 937.6+ KB

# %%
train_df.dtypes
# Out:
# msno                  object
# song_id               object
# source_system_tab     object
# source_screen_name    object
# source_type           object
# target                 int64
# dtype: object

# %%
song_df.shape
# Out:
# (20000, 7)

# %%
song_df.dtypes
# Out:
# song_id         object
# song_length      int64
# genre_ids       object
# artist_name     object
# composer        object
# lyricist        object
# language       float64
# dtype: object

# %%
song_extra_info_df.shape
# Out:
# (2295971, 3)

# %%
song_extra_info_df.dtypes
# Out:
# song_id    object
# name       object
# isrc       object
# dtype: object

# %% [markdown]
# ### LET'S VISUALIZE OUR DATASETS....
#
#
# For this project, we are using content as song features like genre_ids, artist_name, composer, lyricist for our Content-Based Recommendation System.
# So let's focus on these features.

# %%
song_df.head()
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329       726
#
#         artist_name                            composer     lyricist  language
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘       3.0
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY      31.0
# 2      SUPER JUNIOR                                 NaN          NaN      31.0
# 3             S.H.E                                 湯小康          徐世珍       3.0
# 4              貴族精選                         Traditional  Traditional      52.0

# %%
song_df['genre_ids'].value_counts()
# Out:
# 465                7972
# 1609               1185
# 2022               1062
# 921                 823
# 958                 788
#                    ...
# 118|1259              1
# 184                   1
# 465|2189|367          1
# 786|139|125|109       1
# 786|691               1
# Name: genre_ids, Length: 274, dtype: int64

# %% [markdown]
# ### `Bar Plot`
#
# Let's plot top 7 count_values along with their Genre IDs

# %%
song_df['genre_ids'].value_counts()[:7].plot(kind='bar')
plt.xlabel('Genre IDs')
plt.ylabel('Value Counts')
ax = plt.gca()
ax.tick_params(axis='x', labelrotation = 0) # gca() returns current axes (or standalone visualization) in the current figure
plt.title("BarDiagram of Top 7 : Genre_IDs vs their Frequency",
          color="orange",
          fontsize=16);

# %% [markdown]
# From this, Our `song_df` dataset contains large no. of songs with Genre_id with `value 465 `

# %% [markdown]
# ## `Step-3:` Data Preprocessing & Preparing Main Datasets....

# %%
song_df.isna().sum()
# Out:
# song_id            0
# song_length        0
# genre_ids        346
# artist_name        0
# composer        8382
# lyricist       14332
# language           0
# dtype: int64

# %% [markdown]
# ### Filling NaNs/Missing Values with Empty String.

# %%
song_df['genre_ids'].fillna(' ', inplace=True)
song_df['composer'].fillna(' ', inplace=True)
song_df['lyricist'].fillna(' ', inplace=True)

song_df.isna().sum()
# Out:
# song_id        0
# song_length    0
# genre_ids      0
# artist_name    0
# composer       0
# lyricist       0
# language       0
# dtype: int64

# %%
song_extra_info_df.isna().sum()
# Out:
# song_id         0
# name            2
# isrc       136548
# dtype: int64

# %% [markdown]
# We don't use `isrc` attribute in our main dataset. No need to clean it.

# %%
train_df.isna().sum()
# Out:
# msno                    0
# song_id                 0
# source_system_tab      67
# source_screen_name    576
# source_type            50
# target                  0
# dtype: int64

# %% [markdown]
# We only need `msno` and `song_id` in our main datset. No need to clean it.

# %% [markdown]
# ### Preparing Main Dataset

# %%
main_df = train_df.drop(['source_system_tab', 'source_screen_name', 'source_type', 'target'], axis = 1)
main_df.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=

# %% [markdown]
# Renaming `msno` to `user_id` for better understanding...

# %%
## Renaming msno to user_id
main_df.rename(columns={'msno': 'user_id'}, inplace=True)
main_df.head()
# Out:
#                                         user_id  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=

# %% [markdown]
# Merging `main_df` with `song_df`
#
# Droping `song_length` and `language` columns

# %%
## Merging main_df and song_df and Droping Columns

main_df = main_df.merge(song_df, on='song_id')
main_df = main_df.drop(['song_length', 'language'], axis=1)
main_df.head()
# Out:
#                                         user_id  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  hZyOA+0yqClPLt6uIEndf8fG8szH/95eKMbaxLE5z30=
# 2  0LhkakIQDn36HZXI6ClQSO7W7jkpZAy+9MvYgPOZGrA=
# 3  MofmAMt7P8LIcF4+LLlcjyIhYUzmv13L/LRwYFxiGYE=
# 4  U9Z+N+szYGJHTPMn/C0V7yIyIC24fDI0RDRWChXATkg=
#
#                                         song_id genre_ids artist_name  \
# 0  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   Desiigner
# 1  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   Desiigner
# 2  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 3  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 4  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
#
#                    composer lyricist
# 0  Sidney Selby| Adnan Khan
# 1  Sidney Selby| Adnan Khan
# 2                       鄭建浩      鄭建浩
# 3                       鄭建浩      鄭建浩
# 4                       鄭建浩      鄭建浩

# %%
song_extra_info_df.head()
# Out:
#                                         song_id             name          isrc
# 0  LP7pLJoJFBvyuUwvu+oLzjT+bI+UeBPURCecJsX1jjs=               我們  TWUM71200043
# 1  ClazTFnk6r0Bnuie44bocdNMM3rdlrq0bCGAsGUWcHE=  Let Me Love You  QMZSY1600015
# 2  u2ja/bZE3zhCGxvbbOB3zOoUjx27u40cf5g09UXMoKQ=              原諒我  TWA530887303
# 3  92Fqsy0+p6+RHe2EoLKjHahORHR1Kq1TBJoClW9v+Ts=          Classic  USSM11301446
# 4  0QFmz/+rJy1Q56C1DuYqT9hKKqi5TUqx0sN0IwvoHrw=             愛投羅網  TWA471306001

# %% [markdown]
# Merging `song_extra_info_df` and `main_df`
#
# Droping `isrc` attribute.

# %%
## Merging and Droping

main_df = main_df.merge(song_extra_info_df, on='song_id').drop('isrc', axis=1)
main_df.head()
# Out:
#                                         user_id  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  hZyOA+0yqClPLt6uIEndf8fG8szH/95eKMbaxLE5z30=
# 2  0LhkakIQDn36HZXI6ClQSO7W7jkpZAy+9MvYgPOZGrA=
# 3  MofmAMt7P8LIcF4+LLlcjyIhYUzmv13L/LRwYFxiGYE=
# 4  U9Z+N+szYGJHTPMn/C0V7yIyIC24fDI0RDRWChXATkg=
#
#                                         song_id genre_ids artist_name  \
# 0  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   Desiigner
# 1  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   Desiigner
# 2  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 3  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 4  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
#
#                    composer lyricist   name
# 0  Sidney Selby| Adnan Khan           Panda
# 1  Sidney Selby| Adnan Khan           Panda
# 2                       鄭建浩      鄭建浩  我過的很好
# 3                       鄭建浩      鄭建浩  我過的很好
# 4                       鄭建浩      鄭建浩  我過的很好

# %% [markdown]
# Renaming `name` attribute with `song_name`

# %%
## Renaming 
main_df.rename(columns={'name' : 'song_name'}, inplace=True)
main_df.head()
# Out:
#                                         user_id  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  hZyOA+0yqClPLt6uIEndf8fG8szH/95eKMbaxLE5z30=
# 2  0LhkakIQDn36HZXI6ClQSO7W7jkpZAy+9MvYgPOZGrA=
# 3  MofmAMt7P8LIcF4+LLlcjyIhYUzmv13L/LRwYFxiGYE=
# 4  U9Z+N+szYGJHTPMn/C0V7yIyIC24fDI0RDRWChXATkg=
#
#                                         song_id genre_ids artist_name  \
# 0  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   Desiigner
# 1  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   Desiigner
# 2  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 3  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 4  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
#
#                    composer lyricist song_name
# 0  Sidney Selby| Adnan Khan              Panda
# 1  Sidney Selby| Adnan Khan              Panda
# 2                       鄭建浩      鄭建浩     我過的很好
# 3                       鄭建浩      鄭建浩     我過的很好
# 4                       鄭建浩      鄭建浩     我過的很好

# %% [markdown]
# ### Performing Preprocessing for Our constructed `main_df` Dataset

# %%
main_df['genre_ids'].value_counts()
# Out:
# 465                    710
# 458                    400
# 444                     65
# 1609                    57
# 921                     49
# 359                     32
#                         26
# 139                     24
# 2022                    21
# 1259                    20
# 2122                    13
# 139|125|109              7
# 726                      7
# 451                      7
# 437                      7
# 958                      6
# 786|947                  6
# 465|1259                 4
# 1011                     4
# 786                      4
# 947                      4
# 691                      3
# 921|465                  3
# 430                      3
# 921|458                  2
# 458|1287                 2
# 698                      2
# 444|1259                 2
# 829                      2
# 850                      2
# 1152                     1
# 880|458                  1
# 465|829                  1
# 864|857|850|843          1
# 465|798                  1
# 474                      1
# 864|850|726|857|843      1
# 388                      1
# 864|786|850|857|843      1
# 940                      1
# 1609|465                 1
# 465|2122                 1
# 423                      1
# 726|242                  1
# 437|850                  1
# Name: genre_ids, dtype: int64

# %% [markdown]
# You can see there are lots of `|` in genre_ids.
# Replacing `|` with `' '`

# %%
main_df['genre_ids'] = main_df['genre_ids'].str.replace('|', ' ', regex=True)
main_df['genre_ids'].value_counts().tail()
# Out:
# 1609 465    1
# 465 2122    1
# 423         1
# 726 242     1
# 437 850     1
# Name: genre_ids, dtype: int64

# %% [markdown]
# Without using regex=True, Warining Appears:
# FutureWarning: The default value of regex will change from True to False in a future version
#
# Reason: In Series.str.replace, current default value for the param:regex is set to True. In a future version, it will be defaulted to false: regex=False.
# This means in the future, if you want to use regex with str.replace, you will need to set the regex param to True.

# %%
### lets see all tuples values...
# pd.set_option('display.max_rows', None)
# pd.reset_option('display.max_rows')

# %% [markdown]
# In attributes `artist_name`, `composer` and `lyricist`, there are '/' and '|' symbols,
#
# So, replacing that by " ".

# %%
main_df['artist_name'] = main_df['artist_name'].str.replace( '|',' ', regex=True)
main_df['artist_name'] = main_df['artist_name'].str.replace( '/',' ',  regex=True)

main_df['lyricist'] = main_df['lyricist'].str.replace( '|',' ', regex=True)
main_df['lyricist'] = main_df['lyricist'].str.replace( '/',' ', regex=True)

main_df['composer'] = main_df['composer'].str.replace( '|',' ', regex=True)
main_df['composer'] = main_df['composer'].str.replace( '/',' ', regex=True)

# %% [markdown]
# ### Converting string into Lower Case....

# %%
main_df['artist_name']  = main_df['artist_name'].str.lower()
main_df['lyricist']  = main_df['lyricist'].str.lower()
main_df['composer']  = main_df['composer'].str.lower()

# %% [markdown]
# ### Creating new column `song_details` with values concatenating corresoponding values of attributes `artist_name`, `composer`, `lyricist` .

# %%
main_df['song_details'] = main_df['artist_name'] + ' ' +  main_df['lyricist'] + ' ' +  main_df['composer'] + ' ' +  main_df['genre_ids']

# %%
main_df.head()
# Out:
#                                         user_id  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  hZyOA+0yqClPLt6uIEndf8fG8szH/95eKMbaxLE5z30=
# 2  0LhkakIQDn36HZXI6ClQSO7W7jkpZAy+9MvYgPOZGrA=
# 3  MofmAMt7P8LIcF4+LLlcjyIhYUzmv13L/LRwYFxiGYE=
# 4  U9Z+N+szYGJHTPMn/C0V7yIyIC24fDI0RDRWChXATkg=
#
#                                         song_id genre_ids artist_name  \
# 0  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   desiigner
# 1  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   desiigner
# 2  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 3  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 4  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
#
#                    composer lyricist song_name  \
# 0  sidney selby  adnan khan              Panda
# 1  sidney selby  adnan khan              Panda
# 2                       鄭建浩      鄭建浩     我過的很好
# 3                       鄭建浩      鄭建浩     我過的很好
# 4                       鄭建浩      鄭建浩     我過的很好
#
#                                 song_details
# 0  desiigner   sidney selby  adnan khan 1259
# 1  desiigner   sidney selby  adnan khan 1259
# 2                            莊心妍 鄭建浩 鄭建浩 458
# 3                            莊心妍 鄭建浩 鄭建浩 458
# 4                            莊心妍 鄭建浩 鄭建浩 458

# %%
main_df.user_id.value_counts()
# Out:
# EozJegFxTFIWDb9aJ7O8kSUHAgx4ZIvqf7IuN5Zck50=    19
# V5U4EGk2kaSKaUGSwhU6g3HBefxflEvAy1vWPu6UBQs=    18
# Bwg9yS76qujJJeKsYSzfJrMlkjK5Ui7KFkgUcjuXRCg=    12
# W9NYSCff57nmfyYCiX6IbW0/G3YuwC18h/rld+BGxMY=    11
# UzlQoa9tdrcpYdh4wksoh+SpWCFcKvRGPA+xLNqghmo=    11
#                                                 ..
# rb7TT328utsdnd8COyhstig0zciXIURo7M464E60EHg=     1
# hSn7jMfIURFu+1W3PDIDTxbhM5SxRg9VFRoH23Rm2Ic=     1
# yrMfQXudhDaA/bOePZtkKErbjZc5pALG79FHPayEy5U=     1
# iP3eF1In0rH61CfgVmWVYj4CgFcQQ0iVZG7MBA+Plgo=     1
# j2Sx5B7BrjqCiT3ZwWK4AvepwM14QEalhTPi2/sgdG4=     1
# Name: user_id, Length: 975, dtype: int64

# %% [markdown]
# ### Codes which  are written below was just used for debugging and testing purpose at the beginning Phase.
#
# user_history = main_df.groupby(['user_id'])['song_name']
#
#
# for key, item in user_history:
#     print(key)
#     print(item)
#
# user_history_list = user_history.apply(list)
# user_history_list
# user_history_list.keys()
#
# main_df['song_name'].iloc[566]
#
# main_df['song_name'][566]
#
# def user_songs_history(userID):
#
#
#     user_history_values = user_history_list[userID]
#     print(f"User ID: {userID}\n\n")
#     print("Songs History:\n")
#     for i in range(len(user_history_values)):
#         print(f"{i+1}. {user_history_values[i]}\n")
#
# user_songs_history('+6qXndZ2nMn0cyAWZlBfOBGVqolfO2CRo1MdVznK7Kg=')

# %% [markdown]
# ## `Step-4:` Computing Similarities betn Songs using Cosine_similarities.
#
#
# ### Before the computation of Cosine Similarity, we need to remove duplicated or redundant values in song_details column which consists value append from genre_ids, artist_name, composer and lyricist. So, removing user_id from main_df and storing into temp_df. Now, temp_df consists of some duplicated tuples and we remove duplicated tuples and compute cosine_similarity.

# %%
main_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# As main_df contains user_id so there will be rarely duplicated tuples. Here its zero. As Different users can listen to same song so we need to remove user_id and see for duplicate tuples in our dataset.

# %%
temp_df = main_df.copy() # Making duplicate of Original dataset.
temp_df.head()
# Out:
#                                         user_id  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  hZyOA+0yqClPLt6uIEndf8fG8szH/95eKMbaxLE5z30=
# 2  0LhkakIQDn36HZXI6ClQSO7W7jkpZAy+9MvYgPOZGrA=
# 3  MofmAMt7P8LIcF4+LLlcjyIhYUzmv13L/LRwYFxiGYE=
# 4  U9Z+N+szYGJHTPMn/C0V7yIyIC24fDI0RDRWChXATkg=
#
#                                         song_id genre_ids artist_name  \
# 0  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   desiigner
# 1  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   desiigner
# 2  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 3  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 4  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
#
#                    composer lyricist song_name  \
# 0  sidney selby  adnan khan              Panda
# 1  sidney selby  adnan khan              Panda
# 2                       鄭建浩      鄭建浩     我過的很好
# 3                       鄭建浩      鄭建浩     我過的很好
# 4                       鄭建浩      鄭建浩     我過的很好
#
#                                 song_details
# 0  desiigner   sidney selby  adnan khan 1259
# 1  desiigner   sidney selby  adnan khan 1259
# 2                            莊心妍 鄭建浩 鄭建浩 458
# 3                            莊心妍 鄭建浩 鄭建浩 458
# 4                            莊心妍 鄭建浩 鄭建浩 458

# %% [markdown]
# # Computing Cosine Similarities Matrix for unique `song_details` values / for every unique songs with each others.

# %%
temp_df.song_details.duplicated().sum()
# Out:
# 876

# %%
temp_df.shape
# Out:
# (1509, 8)

# %%
temp_df.duplicated().sum()
# Out:
# 0

# %%
temp_df = temp_df.drop('user_id', axis=1) # Removing user_id from temp_df

# %%
temp_df.head()
# Out:
#                                         song_id genre_ids artist_name  \
# 0  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   desiigner
# 1  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=      1259   desiigner
# 2  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 3  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
# 4  skehue/d/R59G71dXYpntDwdjRRPlweN3JE8g40TgZU=       458         莊心妍
#
#                    composer lyricist song_name  \
# 0  sidney selby  adnan khan              Panda
# 1  sidney selby  adnan khan              Panda
# 2                       鄭建浩      鄭建浩     我過的很好
# 3                       鄭建浩      鄭建浩     我過的很好
# 4                       鄭建浩      鄭建浩     我過的很好
#
#                                 song_details
# 0  desiigner   sidney selby  adnan khan 1259
# 1  desiigner   sidney selby  adnan khan 1259
# 2                            莊心妍 鄭建浩 鄭建浩 458
# 3                            莊心妍 鄭建浩 鄭建浩 458
# 4                            莊心妍 鄭建浩 鄭建浩 458

# %%
temp_df.duplicated().sum()
# Out:
# 810

# %% [markdown]
# There are `810`duplicated tuples.
#
# ### Note : These things or concepts or ideas will only be known after proper debugging of outputs at evey steps. So, don't be panic if gets difficult for you to understand. Give some time and do experiments.

# %%
temp_df = temp_df.drop_duplicates()
temp_df.shape
# Out:
# (699, 7)

# %%
1509-810
# Out:
# 699

# %% [markdown]
# There are `699` unique songs in our Dataset.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initializing tfidf vectorizer

tfidf = TfidfVectorizer(analyzer='word', stop_words='english')

# Fit and transform 

tfidf_matrix = tfidf.fit_transform(temp_df['song_details'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarities = cosine_similarity(tfidf_matrix)

# %%
cosine_similarities[:2]
# Out:
# array([[1.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.        , 0.03069817, ..., 0.        , 0.        ,
#         0.        ]])

# %%
similarities = {} ## For storing similarity matrix for every songs.

# %% [markdown]
# ## Commented lines are just for debugging and analysis purpose.
#
# We are storing `50 most similar songs` for each songs of our dataset  in `Similarities Dictionary`.
#
# The code below will store similarities dictionary as :
#
# {song1: [( cosine_similarity, song_name, artist_name), ... to 50 most similar songs with song1],
#
#  song2: [( cosine_similarity, song_name, artist_name), ... to 50 most similar songs with song2],
#
#  ....
#
#  ....}

# %%
for i in range(len(cosine_similarities)):
    # Now we'll sort each element in cosine_similarities and get the indexes of the songs.
    
    similar_score = cosine_similarities[i]
    
#     print(similar_score)
#     print(f"Max:{max(similar_score)}")
#     print(f"Min: {min(similar_score)}")
    
    similar_indices = cosine_similarities[i].argsort()
    
#     print(f"Argsot: {similar_indices}")
#     print(f"INDEX-4328: {similar_score[4328]}")
#     print(similar_indices)
    
# Retrieving 50 index values with maximum similarity and maximum similarity index value will be from the end of similar_indices list
    similar_indices = similar_indices[:-50:-1] 
    
#     print(f"Similar INdices: {similar_indices}")
    
 # After that, we'll store in similarities each name of the 50 most similar songs.
 # Except the first one that is the same song.
    similarities[temp_df['song_name'].iloc[i]] = [(cosine_similarities[i][x], temp_df['song_name'].iloc[x], temp_df['artist_name'].iloc[x]) for x in similar_indices][1:]

# %%
similarities
# Out:
# {'Panda': [(0.6372222477539108, 'Tiimmy Turner', 'desiigner'),
#   (0.2015057132188654, 'Know Better', 'various artists'),
#   (0.17767445140893937,
#    "우리 지금 만나 Let's Meet Now (feat. 장기하와 얼굴들 Kiha & The Faces)",
#    'leessang'),
#   (0.1593882964940167, 'Sometimes', 'geeks'),
#   (0.13735827152835292, 'Turn Around [5|4|3|2|1]', 'flo rida'),
#   (0.13735827152835292,
#    "Where'd You Go (feat. Holly Brook & Jonah Matranga)",
#    'fort minor'),
#   (0.13735827152835292, 'Pull Up (feat. Lil Uzi Vert)', 'wiz khalifa'),
#   (0.12423277761241787, '你不愛我', '玖壹壹'),
#   (0.12347165298926878,
#    'Same Love (feat. Mary Lambert)',
#    'macklemore & ryan lewis'),
#   (0.08657924206912064, '心電感應', 'under lover (地下情人)'),
#   (0.08603402744413446, 'La La La', 'sam smith'),
#   (0.07976388273961801, 'Sing For The Moment', 'eminem'),
#   (0.06128570622004471, 'Trap Queen', 'fetty wap'),
#   (0.05607870563074463, 'Why You Always Hatin?', 'yg'),
#   (0.03903227669831226, 'Me| Myself & I', 'g-eazy'),
#   (0.0, '野子 (Ye Zi)', 'various artists'),
#   (0.0, '新的舊的 (Old And New)', '王笠人'),
#   (0.0, '溫柔 (還你自由版)', '五月天 (mayday)'),
#   (0.0, '反而', '五月天 (mayday)'),
#   (0.0, '任意門', '楊丞琳 (rainie yang)'),
#   (0.0, '明明愛你', '林凡 (freya lim)'),
#   (0.0, 'I Love You無望', '五月天 (mayday)'),
#   (0.0, '波第尼：跳舞娃娃', 'classics joy life'),
#   (0.0, '筆記', '群星'),
#   (0.0, '愛過了頭', '蕭敬騰 (jam hsiao)'),
#   (0.0, '我還想念你', '畢書盡 (bii)'),
#   (0.0, '一同另類', '鄭俊英xyounha'),
#   (0.0, 'Ghost (feat. Nikki Flores)', 'jake miller'),
#   (0.0, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.0, '於是長大了以後', '謝和弦 (r-chord)'),
#   (0.0, '是什麼讓我遇見這樣的你', '白安 (ann)'),
#   (0.0, '你的愛', '王力宏 (leehom wang)'),
#   (0.0, '依然愛你 (Yi Ran Ai Ni)', '王力宏 (leehom wang)'),
#   (0.0, '說分手之後', '小宇-宋念宇'),
#   (0.0, '光陰的故事', 'beijing angelic choir'),
#   (0.0, '從最初到現在', 'ryu'),
#   (0.0, '愛上你是我一生的錯', '曾慶瑜 (regina tsang)'),
#   (0.0, 'Show Me Love', 'robin schulz'),
#   (0.0, '膽小鬼', '梁詠琪 (gigi leung)'),
#   (0.0, '天国の扉', '摩天樓opera'),
#   (0.0, 'Dear Mr.Tomorrow', 'motohiro hata (秦基博)'),
#   (0.0, '一無所有', '徐佳瑩 (lala hsu)'),
#   (0.0, '珊瑚海', '周杰倫 (jay chou)'),
#   (0.0, 'By My Side', 'various artists'),
#   (0.0, '復刻回憶', '薛凱琪 (fiona sit)'),
#   (0.0, 'Russian Roulette', 'red velvet'),
#   (0.0, '放我的真心在你的手心', '張智成 (z-chen chang)'),
#   (0.0, '差一點我們會飛', '哪一天我們會飛')],
#  '我過的很好': [(0.9685502100586879, '幸福離我好遠', '莊心妍'),
#   (0.9685502100586879, '不想管太多', '莊心妍'),
#   (0.1673097962986712, '我知道', '莊心妍'),
#   (0.09196377314756442, '青春無敵 (Invincible)', 'various artists'),
#   (0.07987475588043812, '在你耳邊說 (Come Out Your Way)', 'eric 周興哲'),
#   (0.0743512950772022, '太極拳Cypher (Tai Chi Fist Cypher)', 'various artists'),
#   (0.06856125896306055, '我愛夏天', '脫拉庫 (tolaku)'),
#   (0.06221840787756432, '你好', '王大文'),
#   (0.062187640847996925, '最好的一天 (Best Day of My Life)', '五月天 (mayday)'),
#   (0.06189470702534715, '凍未條', '玖壹壹'),
#   (0.059033033252861696, '愛情掉在哪裡', '井柏然'),
#   (0.05792791748726934, '關於我愛你', '張懸 (deserts xuan)'),
#   (0.055983756193123235, '母系社會', 'amit'),
#   (0.05468620665981936, '飄移', '周杰倫 (jay chou)'),
#   (0.05468620665981936, '我不配', '周杰倫 (jay chou)'),
#   (0.05468620665981936, '麥芽糖', '周杰倫 (jay chou)'),
#   (0.05468620665981936, '床邊故事', '周杰倫 (jay chou)'),
#   (0.05468620665981936, '驚嘆號', '周杰倫 (jay chou)'),
#   (0.05468620665981936, '手寫的從前', '周杰倫 (jay chou)'),
#   (0.05468620665981936, '髮如雪', '周杰倫 (jay chou)'),
#   (0.05468620665981936, '珊瑚海', '周杰倫 (jay chou)'),
#   (0.053119725968399756, '夢醒時分', '伍佰 & china blue'),
#   (0.052899442235746975, '靈魂伴侶 (Soul mate)', '田馥甄 (hebe)'),
#   (0.052899442235746975, '身體都知道 (Your body speaks)', '田馥甄 (hebe)'),
#   (0.05242691472536387, '相愛後動物感傷', '徐佳瑩 (lala hsu)'),
#   (0.05209984491294467, '時間告訴我的事 (Lessons From Time)', '丁噹 (della)'),
#   (0.051832185230446436,
#    '在揮手那天回首 (Looking Back Before Moving Forward)',
#    '麋先生 (mixer)'),
#   (0.051212069283164297, '瓦解', '周杰倫 (jay chou)'),
#   (0.051212069283164297, '你怎麼連話都說不清楚', '周杰倫 (jay chou)'),
#   (0.051212069283164297, '水手怕水', '周杰倫 (jay chou)'),
#   (0.051079335745004686, "別 (Don't)", 's.h.e'),
#   (0.05029822888158676, '左邊', '楊丞琳 (rainie yang)'),
#   (0.04989718145727311, '人在雨中', '張學友 (jacky cheung)'),
#   (0.04988699794643316, '你給我聽好', '陳奕迅 (eason chan)'),
#   (0.049308249116674994, '離心力 (Centrifugal Force)', '楊乃文 (naiwen yang)'),
#   (0.049209135128318975, '壞與更壞', '林宥嘉 (yoga lin)'),
#   (0.048247857134630694, '現在，你在哪裡？', 'various artists'),
#   (0.04602083207804906, '怎麼還不愛 (Why Not Love)', '楊凱琳 (rosie)'),
#   (0.04602083207804906, '一個人也可以幸福 (Happiness For One)', '關詩敏 (sharon kwan)'),
#   (0.04602083207804906, 'Kiss Me', '安心亞 (amber an)'),
#   (0.045918754259288715, '我也不想這樣', '徐佳瑩 (lala hsu)'),
#   (0.04589979882747789, '明天的事情', '徐佳瑩 (lala hsu)'),
#   (0.04524016366716269, '不羈 (BOOGIE)', '吳建豪 (vanness wu)'),
#   (0.04439371505542274, '大笨鐘', '周杰倫 (jay chou)'),
#   (0.04336750575790031, '霸道 (Domineering)', '麋先生 (mixer)'),
#   (0.042026430702879265, '上行之詩 (Pilgrim Song)', 'various artists'),
#   (0.0416696437255625, '再遇見 (Met Again)', '蘇打綠 (sodagreen)'),
#   (0.041355296602618524, '長大以後的世界 (Grown Up)', '王源 (roy wang)')],
#  '帥到分手': [(0.10928620425825526, '美', '王力宏 (leehom wang)'),
#   (0.05672535795644919, '青春無敵 (Invincible)', 'various artists'),
#   (0.04926857570025491, '在你耳邊說 (Come Out Your Way)', 'eric 周興哲'),
#   (0.04716381315621961, '日不落 (Sun will never set)', '蔡依林 (jolin tsai)'),
#   (0.045861578787250674, '太極拳Cypher (Tai Chi Fist Cypher)', 'various artists'),
#   (0.042290152127445864, '我愛夏天', '脫拉庫 (tolaku)'),
#   (0.0383777365536319, '你好', '王大文'),
#   (0.0383587587463309, '最好的一天 (Best Day of My Life)', '五月天 (mayday)'),
#   (0.03817807046682005, '凍未條', '玖壹壹'),
#   (0.03641292465404063, '愛情掉在哪裡', '井柏然'),
#   (0.03573126398222421, '關於我愛你', '張懸 (deserts xuan)'),
#   (0.034532060844282585, '母系社會', 'amit'),
#   (0.033731702624695596, '床邊故事', '周杰倫 (jay chou)'),
#   (0.033731702624695596, '麥芽糖', '周杰倫 (jay chou)'),
#   (0.033731702624695596, '驚嘆號', '周杰倫 (jay chou)'),
#   (0.033731702624695596, '珊瑚海', '周杰倫 (jay chou)'),
#   (0.033731702624695596, '手寫的從前', '周杰倫 (jay chou)'),
#   (0.033731702624695596, '髮如雪', '周杰倫 (jay chou)'),
#   (0.033731702624695596, '飄移', '周杰倫 (jay chou)'),
#   (0.033731702624695596, '我不配', '周杰倫 (jay chou)'),
#   (0.03276546151788433, '夢醒時分', '伍佰 & china blue'),
#   (0.032629585474970545, '靈魂伴侶 (Soul mate)', '田馥甄 (hebe)'),
#   (0.032629585474970545, '身體都知道 (Your body speaks)', '田馥甄 (hebe)'),
#   (0.03233811970259797, '相愛後動物感傷', '徐佳瑩 (lala hsu)'),
#   (0.032136375564104896, '時間告訴我的事 (Lessons From Time)', '丁噹 (della)'),
#   (0.031971276952112763,
#    '在揮手那天回首 (Looking Back Before Moving Forward)',
#    '麋先生 (mixer)'),
#   (0.031588775257367835, '你怎麼連話都說不清楚', '周杰倫 (jay chou)'),
#   (0.031588775257367835, '瓦解', '周杰倫 (jay chou)'),
#   (0.031588775257367835, '水手怕水', '周杰倫 (jay chou)'),
#   (0.03150690217618348, "別 (Don't)", 's.h.e'),
#   (0.031025097603435862, '左邊', '楊丞琳 (rainie yang)'),
#   (0.03077772238248663, '人在雨中', '張學友 (jacky cheung)'),
#   (0.030771440960162624, '你給我聽好', '陳奕迅 (eason chan)'),
#   (0.03069816916359362, '我過的很好', '莊心妍'),
#   (0.03041445544933294, '離心力 (Centrifugal Force)', '楊乃文 (naiwen yang)'),
#   (0.030353319675151893, '壞與更壞', '林宥嘉 (yoga lin)'),
#   (0.029760381429782944, '現在，你在哪裡？', 'various artists'),
#   (0.02838670145571458, 'Kiss Me', '安心亞 (amber an)'),
#   (0.02838670145571458, '一個人也可以幸福 (Happiness For One)', '關詩敏 (sharon kwan)'),
#   (0.02838670145571458, '怎麼還不愛 (Why Not Love)', '楊凱琳 (rosie)'),
#   (0.02832373752317451, '我也不想這樣', '徐佳瑩 (lala hsu)'),
#   (0.028312045379432615, '明天的事情', '徐佳瑩 (lala hsu)'),
#   (0.027905167330513302, '不羈 (BOOGIE)', '吳建豪 (vanness wu)'),
#   (0.0273830584734132, '大笨鐘', '周杰倫 (jay chou)'),
#   (0.02675006911523637, '霸道 (Domineering)', '麋先生 (mixer)'),
#   (0.025922863358677564, '上行之詩 (Pilgrim Song)', 'various artists'),
#   (0.025702788993416166, '再遇見 (Met Again)', '蘇打綠 (sodagreen)'),
#   (0.025508892500685658, '長大以後的世界 (Grown Up)', '王源 (roy wang)')],
#  '迷些路 (Lost On The Way)': [(0.692382296588361, '跟你住', '孫盛希 (shi shi)'),
#   (0.3038804189267837, '母系社會', 'amit'),
#   (0.21652486355119605, '陪他 (Pei Ta)', '游鴻明+彭佳慧'),
#   (0.15171283600272184, '擁抱不算愛情 (Undefined Relationship)', '李佳薇 (jess lee)'),
#   (0.06431241373950292, '青春無敵 (Invincible)', 'various artists'),
#   (0.05585828170927518, '在你耳邊說 (Come Out Your Way)', 'eric 周興哲'),
#   (0.05199559660737489, '太極拳Cypher (Tai Chi Fist Cypher)', 'various artists'),
#   (0.04794648916653688, '我愛夏天', '脫拉庫 (tolaku)'),
#   (0.043510785309063174, '你好', '王大文'),
#   (0.04348926920693567, '最好的一天 (Best Day of My Life)', '五月天 (mayday)'),
#   (0.04328441374531474, '凍未條', '玖壹壹'),
#   (0.04128317846163127, '愛情掉在哪裡', '井柏然'),
#   (0.04051034520442269, '關於我愛你', '張懸 (deserts xuan)'),
#   (0.038243341135067464, '珊瑚海', '周杰倫 (jay chou)'),
#   (0.038243341135067464, '手寫的從前', '周杰倫 (jay chou)'),
#   (0.038243341135067464, '驚嘆號', '周杰倫 (jay chou)'),
#   (0.038243341135067464, '床邊故事', '周杰倫 (jay chou)'),
#   (0.038243341135067464, '飄移', '周杰倫 (jay chou)'),
#   (0.038243341135067464, '髮如雪', '周杰倫 (jay chou)'),
#   (0.038243341135067464, '我不配', '周杰倫 (jay chou)'),
#   (0.038243341135067464, '麥芽糖', '周杰倫 (jay chou)'),
#   (0.0371478646132433, '夢醒時分', '伍佰 & china blue'),
#   (0.03699381505579729, '靈魂伴侶 (Soul mate)', '田馥甄 (hebe)'),
#   (0.03699381505579729, '身體都知道 (Your body speaks)', '田馥甄 (hebe)'),
#   (0.03666336553517689, '相愛後動物感傷', '徐佳瑩 (lala hsu)'),
#   (0.03643463797890043, '時間告訴我的事 (Lessons From Time)', '丁噹 (della)'),
#   (0.03624745731359009,
#    '在揮手那天回首 (Looking Back Before Moving Forward)',
#    '麋先生 (mixer)'),
#   (0.03581379575313976, '水手怕水', '周杰倫 (jay chou)'),
#   (0.03581379575313976, '你怎麼連話都說不清楚', '周杰倫 (jay chou)'),
#   (0.03581379575313976, '瓦解', '周杰倫 (jay chou)'),
#   (0.03572097209083165, "別 (Don't)", 's.h.e'),
#   (0.035174725823898995, '左邊', '楊丞琳 (rainie yang)'),
#   (0.03489426399638964, '人在雨中', '張學友 (jacky cheung)'),
#   (0.03488714242949385, '你給我聽好', '陳奕迅 (eason chan)'),
#   (0.03480407047955569, '我過的很好', '莊心妍'),
#   (0.03448240986017075, '離心力 (Centrifugal Force)', '楊乃文 (naiwen yang)'),
#   (0.034413097133992196, '壞與更壞', '林宥嘉 (yoga lin)'),
#   (0.03374085298901175, '現在，你在哪裡？', 'various artists'),
#   (0.03218344237018797, 'Kiss Me', '安心亞 (amber an)'),
#   (0.03218344237018797, '一個人也可以幸福 (Happiness For One)', '關詩敏 (sharon kwan)'),
#   (0.03218344237018797, '怎麼還不愛 (Why Not Love)', '楊凱琳 (rosie)'),
#   (0.03211205696820792, '我也不想這樣', '徐佳瑩 (lala hsu)'),
#   (0.03209880099216969, '明天的事情', '徐佳瑩 (lala hsu)'),
#   (0.03163750272334765, '不羈 (BOOGIE)', '吳建豪 (vanness wu)'),
#   (0.03104556144620912, '大笨鐘', '周杰倫 (jay chou)'),
#   (0.030327909324436263, '霸道 (Domineering)', '麋先生 (mixer)'),
#   (0.029390064226934146, '上行之詩 (Pilgrim Song)', 'various artists'),
#   (0.029140554763406108, '再遇見 (Met Again)', '蘇打綠 (sodagreen)')],
#  'Bokurano Yume': [(0.40658446132507914,
#    'NEW WORLD MUSIC -instrumeental-',
#    'ikimonogakari (いきものがかり)'),
#   (0.10941102422092082, 'AM04:00', 'aimer'),
#   (0.09568656244460974, 'Broken Night', 'aimer'),
#   (0.07636524515534983, 'NEXT PHASE', 'nitta emi (新田恵海)'),
#   (0.06356569329918349, 'Blaze', 'kalafina'),
#   (0.05409825529032682, 'BUNGAKUSHANO KOIBUMI', 'doriko feat. hatsune miku'),
#   (0.05343569672737866, 'The Reason Born In This World', 'funky monkey babys'),
#   (0.0, 'I Will Be(我會)', 'leona lewis'),
#   (0.0, '新的舊的 (Old And New)', '王笠人'),
#   (0.0, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.0, '一同另類', '鄭俊英xyounha'),
#   (0.0, '愛過了頭', '蕭敬騰 (jam hsiao)'),
#   (0.0, '筆記', '群星'),
#   (0.0, '明明愛你', '林凡 (freya lim)'),
#   (0.0, '任意門', '楊丞琳 (rainie yang)'),
#   (0.0, '野子 (Ye Zi)', 'various artists'),
#   (0.0, '反而', '五月天 (mayday)'),
#   (0.0, '溫柔 (還你自由版)', '五月天 (mayday)'),
#   (0.0, '夠好', '黃美珍 (jane huang)'),
#   (0.0, '波第尼：跳舞娃娃', 'classics joy life'),
#   (0.0, '我還想念你', '畢書盡 (bii)'),
#   (0.0, '差一點我們會飛', '哪一天我們會飛'),
#   (0.0, 'Russian Roulette', 'red velvet'),
#   (0.0, '我愛妳不會改變', '畢書盡 (bii)'),
#   (0.0, 'I Love You無望', '五月天 (mayday)'),
#   (0.0, '於是長大了以後', '謝和弦 (r-chord)'),
#   (0.0, '2012', '五月天 (mayday)'),
#   (0.0, '愛上你是我一生的錯', '曾慶瑜 (regina tsang)'),
#   (0.0, '套不住 (Free Spirit)', '符致逸 (adrian fu)'),
#   (0.0, '該忘了你對不對 (Gai Wang Liao Ni Dui Bu Dui)', '周蕙'),
#   (0.0, '是什麼讓我遇見這樣的你', '白安 (ann)'),
#   (0.0, '你的愛', '王力宏 (leehom wang)'),
#   (0.0, '依然愛你 (Yi Ran Ai Ni)', '王力宏 (leehom wang)'),
#   (0.0, '說分手之後', '小宇-宋念宇'),
#   (0.0, '光陰的故事', 'beijing angelic choir'),
#   (0.0, '從最初到現在', 'ryu'),
#   (0.0, 'Show Me Love', 'robin schulz'),
#   (0.0, '放我的真心在你的手心', '張智成 (z-chen chang)'),
#   (0.0, '膽小鬼', '梁詠琪 (gigi leung)'),
#   (0.0, '天国の扉', '摩天樓opera'),
#   (0.0, 'Dear Mr.Tomorrow', 'motohiro hata (秦基博)'),
#   (0.0, '一無所有', '徐佳瑩 (lala hsu)'),
#   (0.0, '珊瑚海', '周杰倫 (jay chou)'),
#   (0.0, 'By My Side', 'various artists'),
#   (0.0, '復刻回憶', '薛凱琪 (fiona sit)'),
#   (0.0, 'Ghost (feat. Nikki Flores)', 'jake miller'),
#   (0.0, 'Cool Girl', 'tove lo'),
#   (0.0, '最大的缺點', '小樂 (吳思賢) (ben wu)')],
#  'Gobaeghabnida': [(0.22141797308975217, '背影', 'k one'),
#   (0.22141797308975217, '愛很簡單', 's.h.e'),
#   (0.22141797308975217, 'How Deep Is Your Love', 'take that'),
#   (0.05926565601055904, '一眼萬年', 's.h.e'),
#   (0.059208688802944366, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.059208688802944366, "We Don't Talk Any More", 'various artists'),
#   (0.057788821035717586, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.054223437497148384, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.054223437497148384, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.054223437497148384, '癡癡的等', '信 (shin)'),
#   (0.05194186183031002, 'Love Song', 'bigbang'),
#   (0.05194186183031002, 'Peligro', 'reik'),
#   (0.05194186183031002, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.05194186183031002, 'Supermassive Black Hole', 'muse'),
#   (0.05194186183031002, '無字的情批', '黃乙玲'),
#   (0.05194186183031002, '不愛我就離開我 (基地小虎)', '內地華語精選'),
#   (0.05194186183031002, 'YOU & I (BOM Solo)', '2ne1'),
#   (0.05194186183031002, "Baby Don't Cry", 'bigbang'),
#   (0.05194186183031002, 'Good Day', 'the click five'),
#   (0.05194186183031002, '放我去飛', '黃乙玲'),
#   (0.05194186183031002, '千年情', '張秀卿'),
#   (0.05194186183031002, '不讓我的眼淚陪我過夜', '內地華語精選'),
#   (0.05194186183031002, 'Rolling In The Deep', 'adele'),
#   (0.05194186183031002, '狼與美女 (Wolf)', 'exo'),
#   (0.04902591880717422, 'always on my mind(常駐我心)', '純愛西洋對唱情歌cv'),
#   (0.04902591880717422, '清淨法身佛', '齊豫'),
#   (0.04902591880717422, '你的第一', '霍建華'),
#   (0.04902591880717422, '追幸福', '朱海君'),
#   (0.04902591880717422, '男性的本領', '巨星白金系列'),
#   (0.04902591880717422, '雨中即景', '滾石金韻民歌百大精選'),
#   (0.04902591880717422, '我愛的人', '星光幫'),
#   (0.04902591880717422, 'Loving You(愛著你)', 'all about love'),
#   (0.04902591880717422, 'SOS', 'abba'),
#   (0.04902591880717422, 'Raise Your Glass (乾杯狂歡)', 'p!nk'),
#   (0.04902591880717422, '感情路', '翁立友'),
#   (0.04902591880717422, '彩虹天堂', '劉畊宏'),
#   (0.04902591880717422, 'Ma Boy 2 (feat. 효린)', '일렉트로보이즈'),
#   (0.04902591880717422, 'Get It Started (feat. Shakira)', 'pitbull'),
#   (0.04902591880717422, "Nothing's Gonna Change My Love for You", 'westlife'),
#   (0.04902591880717422, '狠不下心', '黃品源'),
#   (0.04902591880717422, '心頭肉', '蔡義德'),
#   (0.04902591880717422, '孤單不孤單', '我要當歌手'),
#   (0.04902591880717422, 'Hey| Soul Sister', 'train'),
#   (0.04902591880717422, '深藍色', '拜爾'),
#   (0.04902591880717422, "I'm home| Dear Dad", 'crispy脆樂團'),
#   (0.04902591880717422, '你別傻了', '周俊偉'),
#   (0.048429942070204075, '倔強', '五月天 (mayday)'),
#   (0.04102875919363281, 'A Beautiful Mess', 'jason mraz')],
#  '忠孝東路走九遍': [(1.0, '忠孝東路走九遍', '動力火車 (power station)'),
#   (1.0, '第一滴淚', '動力火車 (power station)'),
#   (0.1443024502600353, 'How Deep Is Your Love', 'take that'),
#   (0.1443024502600353, '背影', 'k one'),
#   (0.1443024502600353, '愛很簡單', 's.h.e'),
#   (0.0386245942876797, '一眼萬年', 's.h.e'),
#   (0.03858746763744188, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.03858746763744188, "We Don't Talk Any More", 'various artists'),
#   (0.03766211187251932, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.0353384812586496, '癡癡的等', '信 (shin)'),
#   (0.0353384812586496, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.0353384812586496, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.03385153349833841, "Baby Don't Cry", 'bigbang'),
#   (0.03385153349833841, 'Peligro', 'reik'),
#   (0.03385153349833841, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.03385153349833841, '無字的情批', '黃乙玲'),
#   (0.03385153349833841, 'Supermassive Black Hole', 'muse'),
#   (0.03385153349833841, '不愛我就離開我 (基地小虎)', '內地華語精選'),
#   (0.03385153349833841, 'YOU & I (BOM Solo)', '2ne1'),
#   (0.03385153349833841, 'Good Day', 'the click five'),
#   (0.03385153349833841, '放我去飛', '黃乙玲'),
#   (0.03385153349833841, '千年情', '張秀卿'),
#   (0.03385153349833841, '不讓我的眼淚陪我過夜', '內地華語精選'),
#   (0.03385153349833841, 'Rolling In The Deep', 'adele'),
#   (0.03385153349833841, '狼與美女 (Wolf)', 'exo'),
#   (0.03385153349833841, 'Love Song', 'bigbang'),
#   (0.0319511560484618, 'always on my mind(常駐我心)', '純愛西洋對唱情歌cv'),
#   (0.0319511560484618, 'SOS', 'abba'),
#   (0.0319511560484618, '你的第一', '霍建華'),
#   (0.0319511560484618, '追幸福', '朱海君'),
#   (0.0319511560484618, '男性的本領', '巨星白金系列'),
#   (0.0319511560484618, '雨中即景', '滾石金韻民歌百大精選'),
#   (0.0319511560484618, '我愛的人', '星光幫'),
#   (0.0319511560484618, 'Loving You(愛著你)', 'all about love'),
#   (0.0319511560484618, '清淨法身佛', '齊豫'),
#   (0.0319511560484618, '感情路', '翁立友'),
#   (0.0319511560484618, 'Ma Boy 2 (feat. 효린)', '일렉트로보이즈'),
#   (0.0319511560484618, '彩虹天堂', '劉畊宏'),
#   (0.0319511560484618, 'Get It Started (feat. Shakira)', 'pitbull'),
#   (0.0319511560484618, "Nothing's Gonna Change My Love for You", 'westlife'),
#   (0.0319511560484618, '狠不下心', '黃品源'),
#   (0.0319511560484618, '心頭肉', '蔡義德'),
#   (0.0319511560484618, 'Hey| Soul Sister', 'train'),
#   (0.0319511560484618, '孤單不孤單', '我要當歌手'),
#   (0.0319511560484618, 'Raise Your Glass (乾杯狂歡)', 'p!nk'),
#   (0.0319511560484618, '深藍色', '拜爾'),
#   (0.0319511560484618, "I'm home| Dear Dad", 'crispy脆樂團'),
#   (0.0319511560484618, '你別傻了', '周俊偉')],
#  '離心力 (Centrifugal Force)': [(0.7348331049889005, '我給的愛', '楊乃文 (naiwen yang)'),
#   (0.1992241007138975, '明天的事情', '徐佳瑩 (lala hsu)'),
#   (0.18975340124200848, '左邊', '楊丞琳 (rainie yang)'),
#   (0.1506708618321355, '跟你住', '孫盛希 (shi shi)'),
#   (0.1474476296646287, '裝聾作啞 (Zhuang Long Zuo Ya)', '陳小春 (jordan chan)'),
#   (0.1455414920175809, '匿名的好友 (Ni Ming De Hao You)', '楊丞琳 (rainie yang)'),
#   (0.14479746058220747, '一萬零一種可能', '楊丞琳 (rainie yang)'),
#   (0.14372661662015093, '任意門', '楊丞琳 (rainie yang)'),
#   (0.1337926579875099, '千年', '曾靜玟 (jing wen)'),
#   (0.12736329643564898, '這裡還有我', '曾沛慈 (pets tseng)'),
#   (0.09411797253398765, '復刻回憶', '薛凱琪 (fiona sit)'),
#   (0.09111384025684124, '青春無敵 (Invincible)', 'various artists'),
#   (0.0791365501735851, '在你耳邊說 (Come Out Your Way)', 'eric 周興哲'),
#   (0.07366413741727694, '太極拳Cypher (Tai Chi Fist Cypher)', 'various artists'),
#   (0.06816769638329453, '天天夜夜', '飛兒樂團 (f.i.r.)'),
#   (0.06792761304980957, '我愛夏天', '脫拉庫 (tolaku)'),
#   (0.06164338284919018, '你好', '王大文'),
#   (0.06161290016974767, '最好的一天 (Best Day of My Life)', '五月天 (mayday)'),
#   (0.061322673653270245, '凍未條', '玖壹壹'),
#   (0.058487447584902506, '愛情掉在哪裡', '井柏然'),
#   (0.057392545343669644, '關於我愛你', '張懸 (deserts xuan)'),
#   (0.055466352066409, '母系社會', 'amit'),
#   (0.05418079453808656, '床邊故事', '周杰倫 (jay chou)'),
#   (0.05418079453808656, '麥芽糖', '周杰倫 (jay chou)'),
#   (0.05418079453808656, '我不配', '周杰倫 (jay chou)'),
#   (0.05418079453808656, '驚嘆號', '周杰倫 (jay chou)'),
#   (0.05418079453808656, '手寫的從前', '周杰倫 (jay chou)'),
#   (0.05418079453808656, '珊瑚海', '周杰倫 (jay chou)'),
#   (0.05418079453808656, '髮如雪', '周杰倫 (jay chou)'),
#   (0.05418079453808656, '飄移', '周杰倫 (jay chou)'),
#   (0.052628791324229596, '夢醒時分', '伍佰 & china blue'),
#   (0.05241054346269503, '靈魂伴侶 (Soul mate)', '田馥甄 (hebe)'),
#   (0.05241054346269503, '身體都知道 (Your body speaks)', '田馥甄 (hebe)'),
#   (0.051942383070570565, '相愛後動物感傷', '徐佳瑩 (lala hsu)'),
#   (0.05161833605051431, '時間告訴我的事 (Lessons From Time)', '丁噹 (della)'),
#   (0.05135315008956848,
#    '在揮手那天回首 (Looking Back Before Moving Forward)',
#    '麋先生 (mixer)'),
#   (0.05073876527881562, '水手怕水', '周杰倫 (jay chou)'),
#   (0.05073876527881562, '你怎麼連話都說不清楚', '周杰倫 (jay chou)'),
#   (0.05073876527881562, '瓦解', '周杰倫 (jay chou)'),
#   (0.05060725846935497, "別 (Don't)", 's.h.e'),
#   (0.04943602969910341, '人在雨中', '張學友 (jacky cheung)'),
#   (0.04942594030468029, '你給我聽好', '陳奕迅 (eason chan)'),
#   (0.049308249116674994, '我過的很好', '莊心妍'),
#   (0.04875434232199852, '壞與更壞', '林宥嘉 (yoga lin)'),
#   (0.047801948498195836, '現在，你在哪裡？', 'various artists'),
#   (0.04559550569677044, 'Kiss Me', '安心亞 (amber an)'),
#   (0.04559550569677044, '一個人也可以幸福 (Happiness For One)', '關詩敏 (sharon kwan)'),
#   (0.04559550569677044, '怎麼還不愛 (Why Not Love)', '楊凱琳 (rosie)')],
#  '你給我聽好': [(0.6540656300510317, '男人的錯', '陳奕迅 (eason chan)'),
#   (0.45567901989119064, '聖誕結', '陳奕迅 (eason chan)'),
#   (0.44872508838929875, '這樣的一個麻煩(國)', '陳奕迅 (eason chan)'),
#   (0.43792947270752447, '我們都寂寞', '陳奕迅 (eason chan)'),
#   (0.2562000450571138, '讓我留在你身邊', '陳奕迅 (eason chan)'),
#   (0.2272706464956538, '陌生老朋友', '林俊傑 (jj lin)'),
#   (0.22315176411166965, '從最初到現在', 'ryu'),
#   (0.220376050468667, '零度的親吻 (Frozen Kiss)', '林俊傑 (jj lin)'),
#   (0.1672568409376122, '靈魂的共鳴', '林俊傑 (jj lin)'),
#   (0.16512681477920926, 'RHYTHM TA', 'ikon'),
#   (0.16129336642478992, '裂縫中的陽光 (Before Sunrise)', '林俊傑 (jj lin)'),
#   (0.15964147437759005,
#    '十秒的衝動 (10 Seconds Of Insane Bravery)',
#    '林俊傑 (jj lin)'),
#   (0.1493376885423489, '壞與更壞', '林宥嘉 (yoga lin)'),
#   (0.1441045233342095, '失戀無罪', 'a-lin'),
#   (0.13820757595037927, 'P.S.我愛你', 'a-lin'),
#   (0.1364165372816748,
#    'What We Used To Be - Big Baby Driver',
#    'various artists'),
#   (0.13283885761802586, '裝聾作啞 (Zhuang Long Zuo Ya)', '陳小春 (jordan chan)'),
#   (0.12550320966856787, '長大以後的世界 (Grown Up)', '王源 (roy wang)'),
#   (0.12199247387770072, '差一點我們會飛', '哪一天我們會飛'),
#   (0.10650966888429723, '至少還有你', '周華健 (emil chau)'),
#   (0.10414419837524501, '西界', '林俊傑 (jj lin)'),
#   (0.10414419837524501, '曹操', '林俊傑 (jj lin)'),
#   (0.1010075589018708, '愛笑的眼睛', '林俊傑 (jj lin)'),
#   (0.09977630191679347, '招牌動作', '蔡依林 (jolin tsai)'),
#   (0.09683353669626787, '把你寫進我的情歌裡', '陳曉東 (daniel chan)'),
#   (0.09469522486941206, '約定(EXO 2014)', 'exo'),
#   (0.09413736442388615, '原來', '林俊傑 (jj lin)'),
#   (0.09285465158708205, '她說', '林俊傑 (jj lin)'),
#   (0.09218327649455156, '青春無敵 (Invincible)', 'various artists'),
#   (0.0921535046442635,
#    'This man',
#    'hyo rin (sistar) jun hyo sung (secret) hyun a (4minute) nicole (kara) nana (afterschool)'),
#   (0.0860896899141197, '羅密歐與茱麗葉', '林宥嘉 (yoga lin)'),
#   (0.080561095591765, '愛  請問怎麼走', 'a-lin'),
#   (0.08024636682730081,
#    'Once Again - Mad Clown| Kim Na Young (김나영)',
#    'various artists'),
#   (0.0800654046071645, '在你耳邊說 (Come Out Your Way)', 'eric 周興哲'),
#   (0.0775148245941985, '我都記得', 'a-lin'),
#   (0.07452876015463097, '太極拳Cypher (Tai Chi Fist Cypher)', 'various artists'),
#   (0.07350711369784944, '我要快樂 (Desire for happiness)', 'amei (張惠妹)'),
#   (0.0700764383194367, '別說出', '艾怡良 (eve ai)'),
#   (0.06872490411702672, '我愛夏天', '脫拉庫 (tolaku)'),
#   (0.06677150391438746, '好不容易遇見愛', '楊千嬅 (miriam yeung)'),
#   (0.062366913623967554, '你好', '王大文'),
#   (0.06233607315824442, '最好的一天 (Best Day of My Life)', '五月天 (mayday)'),
#   (0.062042440147726245, '凍未條', '玖壹壹'),
#   (0.059173936001175584, '愛情掉在哪裡', '井柏然'),
#   (0.058066182494644014, '關於我愛你', '張懸 (deserts xuan)'),
#   (0.05611738078725102, '母系社會', 'amit'),
#   (0.05481673420327498, '床邊故事', '周杰倫 (jay chou)'),
#   (0.05481673420327498, '我不配', '周杰倫 (jay chou)')],
#  'Heathens': [(0.3462801371643333, 'MADNESS(瘋狂) ', 'muse'),
#   (0.1397373762479083, 'Battle Cry', 'imagine dragons'),
#   (0.1354140012547219, 'Cool Girl', 'tove lo'),
#   (0.1354140012547219, 'Scars', 'tove lo'),
#   (0.13321573276538032, 'Óveður', 'sigur rós'),
#   (0.1317111526975091, 'Bang Bang', 'green day'),
#   (0.13062967458114894, 'Homesick', 'catfish and the bottlemen'),
#   (0.1242159526827837, 'Vibes', 'tove lo'),
#   (0.12395484115748891, 'Scars', 'joseph trapanese  tove lo'),
#   (0.12125908700261966, 'Everglow', 'coldplay'),
#   (0.12091168792311904, 'Untitled #3 (Samskeyti)', 'sigur rós'),
#   (0.10165147977592283, 'Irresistible', 'fall out boy'),
#   (0.08314776850943682, "Ex's & Oh's", 'elle king'),
#   (0.0, '從最初到現在', 'ryu'),
#   (0.0, '任意門', '楊丞琳 (rainie yang)'),
#   (0.0, '野子 (Ye Zi)', 'various artists'),
#   (0.0, '新的舊的 (Old And New)', '王笠人'),
#   (0.0, '溫柔 (還你自由版)', '五月天 (mayday)'),
#   (0.0, '反而', '五月天 (mayday)'),
#   (0.0, '是什麼讓我遇見這樣的你', '白安 (ann)'),
#   (0.0, 'I Love You無望', '五月天 (mayday)'),
#   (0.0, '光陰的故事', 'beijing angelic choir'),
#   (0.0, '波第尼：跳舞娃娃', 'classics joy life'),
#   (0.0, '我還想念你', '畢書盡 (bii)'),
#   (0.0, '差一點我們會飛', '哪一天我們會飛'),
#   (0.0, 'Russian Roulette', 'red velvet'),
#   (0.0, '我愛妳不會改變', '畢書盡 (bii)'),
#   (0.0, 'I Will Be(我會)', 'leona lewis'),
#   (0.0, '你的愛', '王力宏 (leehom wang)'),
#   (0.0, '明明愛你', '林凡 (freya lim)'),
#   (0.0, '筆記', '群星'),
#   (0.0, '愛過了頭', '蕭敬騰 (jam hsiao)'),
#   (0.0, '愛上你是我一生的錯', '曾慶瑜 (regina tsang)'),
#   (0.0, 'Show Me Love', 'robin schulz'),
#   (0.0, '膽小鬼', '梁詠琪 (gigi leung)'),
#   (0.0, '天国の扉', '摩天樓opera'),
#   (0.0, 'Dear Mr.Tomorrow', 'motohiro hata (秦基博)'),
#   (0.0, '一無所有', '徐佳瑩 (lala hsu)'),
#   (0.0, '珊瑚海', '周杰倫 (jay chou)'),
#   (0.0, 'By My Side', 'various artists'),
#   (0.0, '復刻回憶', '薛凱琪 (fiona sit)'),
#   (0.0, 'Ghost (feat. Nikki Flores)', 'jake miller'),
#   (0.0, '放我的真心在你的手心', '張智成 (z-chen chang)'),
#   (0.0, '說分手之後', '小宇-宋念宇'),
#   (0.0, '於是長大了以後', '謝和弦 (r-chord)'),
#   (0.0, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.0, '夠好', '黃美珍 (jane huang)'),
#   (0.0, '一同另類', '鄭俊英xyounha')],
#  'Hey Mama (feat. Nicki Minaj| Bebe Rexha & Afrojack)': [(0.5002192706286799,
#    'Play Hard (feat. Ne-Yo & Akon)',
#    'david guetta'),
#   (0.12455840407417743, 'Bang Bang', 'nicki minaj jessie j ariana grande'),
#   (0.11990251168404592, '愛很簡單', '陶喆 (david tao)'),
#   (0.09949148110117144, 'Rock N Roll (Explicit Version)', 'avril lavigne'),
#   (0.09572883948445152, 'Angel Grove', 'various artists'),
#   (0.09572883948445152, 'Warm Water (Snakehips Remix)', 'various artists'),
#   (0.0938095299422904, 'Blaze', 'colbie caillat'),
#   (0.0936621937792395, 'Tiimmy Turner', 'desiigner'),
#   (0.090241611482769, 'Super跩', '安心亞 (amber an)'),
#   (0.08753408979959935, '#SELFIE', 'the chainsmokers'),
#   (0.08544359264552456, 'Tell Me If You Wanna Go Home', 'various artists'),
#   (0.0839531910576256, 'Anywhere You Go (feat. Timmy Trumpet)', 'nervo'),
#   (0.07423948237192478, 'Me| Myself & I', 'g-eazy'),
#   (0.0697640429827746, 'Lion Heart', "girls' generation (少女時代)"),
#   (0.06603833233131687, 'Homesick', 'catfish and the bottlemen'),
#   (0.05422745569826938, 'Fakin It (feat. Ofelia K)', 'kaskade  felix cartal'),
#   (0.04126494033614965, 'Rather Be (feat. Jess Glynne)', 'clean bandit'),
#   (0.040429986720393905, 'Venus', 'lady gaga'),
#   (0.040253808489661196, 'Good For You', 'selena gomez'),
#   (0.03806214028070261, 'Pandora', 'various artists'),
#   (0.03323310436846632, 'I Took A Pill In Ibiza', 'mike posner'),
#   (0.03170588089365623, 'Daisy', 'zedd'),
#   (0.03110875514100201, 'Beautiful Now', 'zedd'),
#   (0.030125215156389027, '閃亮的女孩', '羅百吉 (jerry lo)'),
#   (0.02990912595998469, 'Shine', 'years & years'),
#   (0.0298617004193962, 'I Wanna Know', 'alesso'),
#   (0.027267282404734156,
#    "Don't You Worry Child (feat. John Martin)",
#    'swedish house mafia'),
#   (0.02537602031262675, 'Summer', 'calvin harris'),
#   (0.020647469239305483, 'This Is What You Came For', 'calvin harris'),
#   (0.017261400885841792, 'Millionaire', 'digital farm animals  cash cash'),
#   (0.014870510516393348, 'Closer', 'the chainsmokers'),
#   (0.014359830288907059, 'Show Me Love', 'robin schulz'),
#   (0.0, '我愛妳不會改變', '畢書盡 (bii)'),
#   (0.0, '波第尼：跳舞娃娃', 'classics joy life'),
#   (0.0, '我還想念你', '畢書盡 (bii)'),
#   (0.0, '差一點我們會飛', '哪一天我們會飛'),
#   (0.0, 'Russian Roulette', 'red velvet'),
#   (0.0, 'Dear Mr.Tomorrow', 'motohiro hata (秦基博)'),
#   (0.0, '反而', '五月天 (mayday)'),
#   (0.0, '天国の扉', '摩天樓opera'),
#   (0.0, '膽小鬼', '梁詠琪 (gigi leung)'),
#   (0.0, 'I Will Be(我會)', 'leona lewis'),
#   (0.0, '夠好', '黃美珍 (jane huang)'),
#   (0.0, 'Cool Girl', 'tove lo'),
#   (0.0, '2012', '五月天 (mayday)'),
#   (0.0, 'I Love You無望', '五月天 (mayday)'),
#   (0.0, '於是長大了以後', '謝和弦 (r-chord)'),
#   (0.0, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele')],
#  '怎麼還不愛 (Why Not Love)': [(0.2862417738227268, '愛情掉在哪裡', '井柏然'),
#   (0.17577445910363038, '自己 (Be Myself)', '蔡旻佑 (evan yo)'),
#   (0.12350883611519449, '別說出', '艾怡良 (eve ai)'),
#   (0.08503921387523469, '青春無敵 (Invincible)', 'various artists'),
#   (0.07386045848346785, '在你耳邊說 (Come Out Your Way)', 'eric 周興哲'),
#   (0.06875289548880734, '太極拳Cypher (Tai Chi Fist Cypher)', 'various artists'),
#   (0.06339882939730677, '我愛夏天', '脫拉庫 (tolaku)'),
#   (0.05753357342120872, '你好', '王大文'),
#   (0.05750512304430336, '最好的一天 (Best Day of My Life)', '五月天 (mayday)'),
#   (0.05723424614198626, '凍未條', '玖壹壹'),
#   (0.05356614236175792, '關於我愛你', '張懸 (deserts xuan)'),
#   (0.051768369799342975, '母系社會', 'amit'),
#   (0.050568521331846056, '珊瑚海', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '飄移', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '麥芽糖', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '我不配', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '床邊故事', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '驚嘆號', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '髮如雪', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '手寫的從前', '周杰倫 (jay chou)'),
#   (0.04911999130757981, '夢醒時分', '伍佰 & china blue'),
#   (0.04891629419062664, '靈魂伴侶 (Soul mate)', '田馥甄 (hebe)'),
#   (0.04891629419062664, '身體都知道 (Your body speaks)', '田馥甄 (hebe)'),
#   (0.04847934639431424, '相愛後動物感傷', '徐佳瑩 (lala hsu)'),
#   (0.048176903826132315, '時間告訴我的事 (Lessons From Time)', '丁噹 (della)'),
#   (0.047929398007191835,
#    '在揮手那天回首 (Looking Back Before Moving Forward)',
#    '麋先生 (mixer)'),
#   (0.04735597468120723, '瓦解', '周杰倫 (jay chou)'),
#   (0.04735597468120723, '你怎麼連話都說不清楚', '周杰倫 (jay chou)'),
#   (0.04735597468120723, '水手怕水', '周杰倫 (jay chou)'),
#   (0.0472332355269333, "別 (Don't)", 's.h.e'),
#   (0.04651094335313323, '左邊', '楊丞琳 (rainie yang)'),
#   (0.0461400934355728, '人在雨中', '張學友 (jacky cheung)'),
#   (0.04613067670845647, '你給我聽好', '陳奕迅 (eason chan)'),
#   (0.04602083207804906, '我過的很好', '莊心妍'),
#   (0.04559550569677044, '離心力 (Centrifugal Force)', '楊乃文 (naiwen yang)'),
#   (0.045503854654568084, '壞與更壞', '林宥嘉 (yoga lin)'),
#   (0.044614957623694364, '現在，你在哪裡？', 'various artists'),
#   (0.04255561997789913, 'Kiss Me', '安心亞 (amber an)'),
#   (0.04255561997789913, '一個人也可以幸福 (Happiness For One)', '關詩敏 (sharon kwan)'),
#   (0.04246122827163944, '我也不想這樣', '徐佳瑩 (lala hsu)'),
#   (0.04244370011936069, '明天的事情', '徐佳瑩 (lala hsu)'),
#   (0.04183373324264654, '不羈 (BOOGIE)', '吳建豪 (vanness wu)'),
#   (0.041051019331891175, '大笨鐘', '周杰倫 (jay chou)'),
#   (0.040102080103476365, '霸道 (Domineering)', '麋先生 (mixer)'),
#   (0.0388619834379809, '上行之詩 (Pilgrim Song)', 'various artists'),
#   (0.03853206130632526, '再遇見 (Met Again)', '蘇打綠 (sodagreen)'),
#   (0.03824138345238158, '長大以後的世界 (Grown Up)', '王源 (roy wang)'),
#   (0.037813180890223924, '不敢哭', '梁心頤 (lara)')],
#  '一個人也可以幸福 (Happiness For One)': [(0.17741029954350696,
#    '我不是你該愛的那個人',
#    '曾沛慈 (pets tseng)'),
#   (0.14239237708001723, '幸福不是情歌【三立偶像劇[兩個爸爸]片尾曲】', '劉若英 (rene liu)'),
#   (0.10545489115560809,
#    'TOP SECRET (Original Title : Shake The Tree)',
#    "girls' generation (少女時代)"),
#   (0.08503921387523469, '青春無敵 (Invincible)', 'various artists'),
#   (0.07386045848346785, '在你耳邊說 (Come Out Your Way)', 'eric 周興哲'),
#   (0.06875289548880734, '太極拳Cypher (Tai Chi Fist Cypher)', 'various artists'),
#   (0.06339882939730677, '我愛夏天', '脫拉庫 (tolaku)'),
#   (0.05753357342120872, '你好', '王大文'),
#   (0.05750512304430336, '最好的一天 (Best Day of My Life)', '五月天 (mayday)'),
#   (0.05723424614198626, '凍未條', '玖壹壹'),
#   (0.054588046669623864, '愛情掉在哪裡', '井柏然'),
#   (0.05356614236175792, '關於我愛你', '張懸 (deserts xuan)'),
#   (0.051768369799342975, '母系社會', 'amit'),
#   (0.050568521331846056, '床邊故事', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '麥芽糖', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '髮如雪', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '手寫的從前', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '珊瑚海', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '飄移', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '我不配', '周杰倫 (jay chou)'),
#   (0.050568521331846056, '驚嘆號', '周杰倫 (jay chou)'),
#   (0.04911999130757981, '夢醒時分', '伍佰 & china blue'),
#   (0.04891629419062664, '身體都知道 (Your body speaks)', '田馥甄 (hebe)'),
#   (0.04891629419062664, '靈魂伴侶 (Soul mate)', '田馥甄 (hebe)'),
#   (0.04847934639431424, '相愛後動物感傷', '徐佳瑩 (lala hsu)'),
#   (0.048176903826132315, '時間告訴我的事 (Lessons From Time)', '丁噹 (della)'),
#   (0.047929398007191835,
#    '在揮手那天回首 (Looking Back Before Moving Forward)',
#    '麋先生 (mixer)'),
#   (0.04735597468120723, '瓦解', '周杰倫 (jay chou)'),
#   (0.04735597468120723, '你怎麼連話都說不清楚', '周杰倫 (jay chou)'),
#   (0.04735597468120723, '水手怕水', '周杰倫 (jay chou)'),
#   (0.0472332355269333, "別 (Don't)", 's.h.e'),
#   (0.04651094335313323, '左邊', '楊丞琳 (rainie yang)'),
#   (0.0461400934355728, '人在雨中', '張學友 (jacky cheung)'),
#   (0.04613067670845647, '你給我聽好', '陳奕迅 (eason chan)'),
#   (0.04602083207804906, '我過的很好', '莊心妍'),
#   (0.04559550569677044, '離心力 (Centrifugal Force)', '楊乃文 (naiwen yang)'),
#   (0.045503854654568084, '壞與更壞', '林宥嘉 (yoga lin)'),
#   (0.044614957623694364, '現在，你在哪裡？', 'various artists'),
#   (0.04255561997789913, 'Kiss Me', '安心亞 (amber an)'),
#   (0.04255561997789913, '怎麼還不愛 (Why Not Love)', '楊凱琳 (rosie)'),
#   (0.04246122827163944, '我也不想這樣', '徐佳瑩 (lala hsu)'),
#   (0.04244370011936069, '明天的事情', '徐佳瑩 (lala hsu)'),
#   (0.04183373324264654, '不羈 (BOOGIE)', '吳建豪 (vanness wu)'),
#   (0.041051019331891175, '大笨鐘', '周杰倫 (jay chou)'),
#   (0.040102080103476365, '霸道 (Domineering)', '麋先生 (mixer)'),
#   (0.0388619834379809, '上行之詩 (Pilgrim Song)', 'various artists'),
#   (0.03853206130632526, '再遇見 (Met Again)', '蘇打綠 (sodagreen)'),
#   (0.03824138345238158, '長大以後的世界 (Grown Up)', '王源 (roy wang)')],
#  '愛一直閃亮': [(0.12997745995430413, '愛很簡單', 's.h.e'),
#   (0.12997745995430413, 'How Deep Is Your Love', 'take that'),
#   (0.12997745995430413, '背影', 'k one'),
#   (0.034790307775310975, '一眼萬年', 's.h.e'),
#   (0.034756866709786255, "We Don't Talk Any More", 'various artists'),
#   (0.034756866709786255, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.03392337156357102, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.03183040914665707, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.03183040914665707, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.03183040914665707, '癡癡的等', '信 (shin)'),
#   (0.03049107157739394, 'Rolling In The Deep', 'adele'),
#   (0.03049107157739394, "Baby Don't Cry", 'bigbang'),
#   (0.03049107157739394, '放我去飛', '黃乙玲'),
#   (0.03049107157739394, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.03049107157739394, 'Peligro', 'reik'),
#   (0.03049107157739394, 'YOU & I (BOM Solo)', '2ne1'),
#   (0.03049107157739394, '狼與美女 (Wolf)', 'exo'),
#   (0.03049107157739394, 'Love Song', 'bigbang'),
#   (0.03049107157739394, '無字的情批', '黃乙玲'),
#   (0.03049107157739394, '千年情', '張秀卿'),
#   (0.03049107157739394, 'Good Day', 'the click five'),
#   (0.03049107157739394, '不愛我就離開我 (基地小虎)', '內地華語精選'),
#   (0.03049107157739394, 'Supermassive Black Hole', 'muse'),
#   (0.03049107157739394, '不讓我的眼淚陪我過夜', '內地華語精選'),
#   (0.028779345730436452, '你的第一', '霍建華'),
#   (0.028779345730436452, '男性的本領', '巨星白金系列'),
#   (0.028779345730436452, '雨中即景', '滾石金韻民歌百大精選'),
#   (0.028779345730436452, 'Loving You(愛著你)', 'all about love'),
#   (0.028779345730436452, '我愛的人', '星光幫'),
#   (0.028779345730436452, 'SOS', 'abba'),
#   (0.028779345730436452, '孤單不孤單', '我要當歌手'),
#   (0.028779345730436452, '感情路', '翁立友'),
#   (0.028779345730436452, 'Ma Boy 2 (feat. 효린)', '일렉트로보이즈'),
#   (0.028779345730436452, "Nothing's Gonna Change My Love for You", 'westlife'),
#   (0.028779345730436452, '深藍色', '拜爾'),
#   (0.028779345730436452, 'always on my mind(常駐我心)', '純愛西洋對唱情歌cv'),
#   (0.028779345730436452, 'Raise Your Glass (乾杯狂歡)', 'p!nk'),
#   (0.028779345730436452, 'Hey| Soul Sister', 'train'),
#   (0.028779345730436452, '心頭肉', '蔡義德'),
#   (0.028779345730436452, '狠不下心', '黃品源'),
#   (0.028779345730436452, 'Get It Started (feat. Shakira)', 'pitbull'),
#   (0.028779345730436452, '彩虹天堂', '劉畊宏'),
#   (0.028779345730436452, '清淨法身佛', '齊豫'),
#   (0.028779345730436452, '追幸福', '朱海君'),
#   (0.028779345730436452, "I'm home| Dear Dad", 'crispy脆樂團'),
#   (0.028779345730436452, '你別傻了', '周俊偉'),
#   (0.028779345730436452, 'Gobaeghabnida', 'ftisland'),
#   (0.02842949363224281, '倔強', '五月天 (mayday)')],
#  'Mr. Simple': [(0.3598112598438472, 'Devil', 'super junior'),
#   (0.1758207683343126, 'How Deep Is Your Love', 'take that'),
#   (0.1758207683343126, '背影', 'k one'),
#   (0.1758207683343126, '愛很簡單', 's.h.e'),
#   (0.1668836700343052, 'Ready 2 Love', 'henry (super junior-m)'),
#   (0.047060918453036976, '一眼萬年', 's.h.e'),
#   (0.04701568265725714, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.04701568265725714, "We Don't Talk Any More", 'various artists'),
#   (0.045888212116888025, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.04305705769699075, '癡癡的等', '信 (shin)'),
#   (0.04305705769699075, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.04305705769699075, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.041245333105899014, '無字的情批', '黃乙玲'),
#   (0.041245333105899014, 'YOU & I (BOM Solo)', '2ne1'),
#   (0.041245333105899014, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.041245333105899014, '不愛我就離開我 (基地小虎)', '內地華語精選'),
#   (0.041245333105899014, "Baby Don't Cry", 'bigbang'),
#   (0.041245333105899014, 'Good Day', 'the click five'),
#   (0.041245333105899014, 'Peligro', 'reik'),
#   (0.041245333105899014, 'Supermassive Black Hole', 'muse'),
#   (0.041245333105899014, '不讓我的眼淚陪我過夜', '內地華語精選'),
#   (0.041245333105899014, '狼與美女 (Wolf)', 'exo'),
#   (0.041245333105899014, '千年情', '張秀卿'),
#   (0.041245333105899014, 'Love Song', 'bigbang'),
#   (0.041245333105899014, 'Rolling In The Deep', 'adele'),
#   (0.041245333105899014, '放我去飛', '黃乙玲'),
#   (0.038929878151666375, '感情路', '翁立友'),
#   (0.038929878151666375, 'Loving You(愛著你)', 'all about love'),
#   (0.038929878151666375, 'always on my mind(常駐我心)', '純愛西洋對唱情歌cv'),
#   (0.038929878151666375, 'Ma Boy 2 (feat. 효린)', '일렉트로보이즈'),
#   (0.038929878151666375, "I'm home| Dear Dad", 'crispy脆樂團'),
#   (0.038929878151666375, '你別傻了', '周俊偉'),
#   (0.038929878151666375, "Nothing's Gonna Change My Love for You", 'westlife'),
#   (0.038929878151666375, '深藍色', '拜爾'),
#   (0.038929878151666375, '你的第一', '霍建華'),
#   (0.038929878151666375, '孤單不孤單', '我要當歌手'),
#   (0.038929878151666375, '男性的本領', '巨星白金系列'),
#   (0.038929878151666375, '雨中即景', '滾石金韻民歌百大精選'),
#   (0.038929878151666375, '我愛的人', '星光幫'),
#   (0.038929878151666375, 'Raise Your Glass (乾杯狂歡)', 'p!nk'),
#   (0.038929878151666375, 'Hey| Soul Sister', 'train'),
#   (0.038929878151666375, 'Get It Started (feat. Shakira)', 'pitbull'),
#   (0.038929878151666375, '心頭肉', '蔡義德'),
#   (0.038929878151666375, '狠不下心', '黃品源'),
#   (0.038929878151666375, 'SOS', 'abba'),
#   (0.038929878151666375, 'Gobaeghabnida', 'ftisland'),
#   (0.038929878151666375, '清淨法身佛', '齊豫'),
#   (0.038929878151666375, '追幸福', '朱海君')],
#  '第一個想到你 (Think Of You First)': [(1.0,
#    '第一個想到你 (Think Of You First)',
#    '韋禮安 (william wei)'),
#   (0.18734998152269466, '擁抱', '蘇永康 (william so)'),
#   (0.12292305262823847, '一點點', '王心凌 (cyndi wang)'),
#   (0.09150574067271013, '我愛你那麼多', '蕭亞軒 (elva hsiao)'),
#   (0.08706614818800694, '該忘了你對不對 (Gai Wang Liao Ni Dui Bu Dui)', '周蕙'),
#   (0.08164832808379989, '靈魂的共鳴', '林俊傑 (jj lin)'),
#   (0.08147844496432251, '香格里拉', '魏如萱 (waa wei)'),
#   (0.07578967774811879, '愛過了頭', '蕭敬騰 (jam hsiao)'),
#   (0.07449913501801056, '背影', 'k one'),
#   (0.07449913501801056, 'How Deep Is Your Love', 'take that'),
#   (0.07449913501801056, '愛很簡單', 's.h.e'),
#   (0.0742047175098475, 'Homesick', 'catfish and the bottlemen'),
#   (0.07106419654278404, '裝聾作啞 (Zhuang Long Zuo Ya)', '陳小春 (jordan chan)'),
#   (0.06841721982521164, '別說出', '艾怡良 (eve ai)'),
#   (0.05896689114214707, 'True Colors', 'the weeknd'),
#   (0.01994074847425273, '一眼萬年', 's.h.e'),
#   (0.019921581070484813, "We Don't Talk Any More", 'various artists'),
#   (0.019921581070484813, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.01944384695061067, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.018244224418056863, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.018244224418056863, '癡癡的等', '信 (shin)'),
#   (0.018244224418056863, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.017476556774433827, '不讓我的眼淚陪我過夜', '內地華語精選'),
#   (0.017476556774433827, 'Good Day', 'the click five'),
#   (0.017476556774433827, 'Supermassive Black Hole', 'muse'),
#   (0.017476556774433827, "Baby Don't Cry", 'bigbang'),
#   (0.017476556774433827, '無字的情批', '黃乙玲'),
#   (0.017476556774433827, 'YOU & I (BOM Solo)', '2ne1'),
#   (0.017476556774433827, 'Peligro', 'reik'),
#   (0.017476556774433827, 'Rolling In The Deep', 'adele'),
#   (0.017476556774433827, '不愛我就離開我 (基地小虎)', '內地華語精選'),
#   (0.017476556774433827, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.017476556774433827, 'Love Song', 'bigbang'),
#   (0.017476556774433827, '千年情', '張秀卿'),
#   (0.017476556774433827, '狼與美女 (Wolf)', 'exo'),
#   (0.017476556774433827, '放我去飛', '黃乙玲'),
#   (0.016495447472627676, '狠不下心', '黃品源'),
#   (0.016495447472627676, '你別傻了', '周俊偉'),
#   (0.016495447472627676, '追幸福', '朱海君'),
#   (0.016495447472627676, "Nothing's Gonna Change My Love for You", 'westlife'),
#   (0.016495447472627676, "I'm home| Dear Dad", 'crispy脆樂團'),
#   (0.016495447472627676, '感情路', '翁立友'),
#   (0.016495447472627676, '孤單不孤單', '我要當歌手'),
#   (0.016495447472627676, '我愛的人', '星光幫'),
#   (0.016495447472627676, 'SOS', 'abba'),
#   (0.016495447472627676, '心頭肉', '蔡義德'),
#   (0.016495447472627676, 'Ma Boy 2 (feat. 효린)', '일렉트로보이즈'),
#   (0.016495447472627676, 'Loving You(愛著你)', 'all about love')],
#  '甘心替代你': [(0.24602973415541635, '你的眼睛背叛你的心', '鄭中基 (ronald cheng)'),
#   (0.1021893599352697, '背影', 'k one'),
#   (0.1021893599352697, '愛很簡單', 's.h.e'),
#   (0.1021893599352697, 'How Deep Is Your Love', 'take that'),
#   (0.027352429296279207, '一眼萬年', 's.h.e'),
#   (0.027326137652460916, "We Don't Talk Any More", 'various artists'),
#   (0.027326137652460916, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.026670836836990033, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.02502533237930788, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.02502533237930788, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.02502533237930788, '癡癡的等', '信 (shin)'),
#   (0.023972334044147482, 'YOU & I (BOM Solo)', '2ne1'),
#   (0.023972334044147482, 'Rolling In The Deep', 'adele'),
#   (0.023972334044147482, "Baby Don't Cry", 'bigbang'),
#   (0.023972334044147482, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.023972334044147482, '千年情', '張秀卿'),
#   (0.023972334044147482, '不讓我的眼淚陪我過夜', '內地華語精選'),
#   (0.023972334044147482, 'Supermassive Black Hole', 'muse'),
#   (0.023972334044147482, 'Good Day', 'the click five'),
#   (0.023972334044147482, '不愛我就離開我 (基地小虎)', '內地華語精選'),
#   (0.023972334044147482, '狼與美女 (Wolf)', 'exo'),
#   (0.023972334044147482, '放我去飛', '黃乙玲'),
#   (0.023972334044147482, 'Love Song', 'bigbang'),
#   (0.023972334044147482, '無字的情批', '黃乙玲'),
#   (0.023972334044147482, 'Peligro', 'reik'),
#   (0.022626560948206545, '你的第一', '霍建華'),
#   (0.022626560948206545, 'Loving You(愛著你)', 'all about love'),
#   (0.022626560948206545, 'SOS', 'abba'),
#   (0.022626560948206545, '我愛的人', '星光幫'),
#   (0.022626560948206545, '雨中即景', '滾石金韻民歌百大精選'),
#   (0.022626560948206545, '男性的本領', '巨星白金系列'),
#   (0.022626560948206545, '孤單不孤單', '我要當歌手'),
#   (0.022626560948206545, 'Ma Boy 2 (feat. 효린)', '일렉트로보이즈'),
#   (0.022626560948206545, '你別傻了', '周俊偉'),
#   (0.022626560948206545, "Nothing's Gonna Change My Love for You", 'westlife'),
#   (0.022626560948206545, '深藍色', '拜爾'),
#   (0.022626560948206545, 'always on my mind(常駐我心)', '純愛西洋對唱情歌cv'),
#   (0.022626560948206545, 'Raise Your Glass (乾杯狂歡)', 'p!nk'),
#   (0.022626560948206545, 'Hey| Soul Sister', 'train'),
#   (0.022626560948206545, '心頭肉', '蔡義德'),
#   (0.022626560948206545, '狠不下心', '黃品源'),
#   (0.022626560948206545, 'Get It Started (feat. Shakira)', 'pitbull'),
#   (0.022626560948206545, '彩虹天堂', '劉畊宏'),
#   (0.022626560948206545, '清淨法身佛', '齊豫'),
#   (0.022626560948206545, '追幸福', '朱海君'),
#   (0.022626560948206545, "I'm home| Dear Dad", 'crispy脆樂團'),
#   (0.022626560948206545, '感情路', '翁立友'),
#   (0.022626560948206545, 'Gobaeghabnida', 'ftisland')],
#  '有愛到就好': [(1.0000000000000002, '錯的人', '蕭亞軒 (elva hsiao)'),
#   (1.0000000000000002, '鑽石糖', '蕭亞軒 (elva hsiao)'),
#   (0.6618689399679732, '我愛你那麼多', '蕭亞軒 (elva hsiao)'),
#   (0.28388632644714135, '疼惜', '蕭煌奇 (ricky hsiao)'),
#   (0.27437557481711505, '太溫柔', '蕭賀碩 (debbie hsiao)'),
#   (0.20756450682903219, '鈴鈴', '蕭敬騰 (jam hsiao)'),
#   (0.16335730434785134, '愛過了頭', '蕭敬騰 (jam hsiao)'),
#   (0.15526417144236224, '愛很簡單', 's.h.e'),
#   (0.15526417144236224, 'How Deep Is Your Love', 'take that'),
#   (0.15526417144236224, '背影', 'k one'),
#   (0.15026529934583535, '沒那麽簡單', '黃小琥 (tiger huang)'),
#   (0.041558654191715165, '一眼萬年', 's.h.e'),
#   (0.04151870727066693, "We Don't Talk Any More", 'various artists'),
#   (0.04151870727066693, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.04052305823025763, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.038022916470014025, '癡癡的等', '信 (shin)'),
#   (0.038022916470014025, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.038022916470014025, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.03642301493288307, '千年情', '張秀卿'),
#   (0.03642301493288307, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.03642301493288307, '不讓我的眼淚陪我過夜', '內地華語精選'),
#   (0.03642301493288307, '不愛我就離開我 (基地小虎)', '內地華語精選'),
#   (0.03642301493288307, 'Rolling In The Deep', 'adele'),
#   (0.03642301493288307, "Baby Don't Cry", 'bigbang'),
#   (0.03642301493288307, 'Love Song', 'bigbang'),
#   (0.03642301493288307, '放我去飛', '黃乙玲'),
#   (0.03642301493288307, 'Peligro', 'reik'),
#   (0.03642301493288307, '無字的情批', '黃乙玲'),
#   (0.03642301493288307, 'Supermassive Black Hole', 'muse'),
#   (0.03642301493288307, 'Good Day', 'the click five'),
#   (0.03642301493288307, 'YOU & I (BOM Solo)', '2ne1'),
#   (0.03642301493288307, '狼與美女 (Wolf)', 'exo'),
#   (0.03437827813422763, 'Loving You(愛著你)', 'all about love'),
#   (0.03437827813422763, '你的第一', '霍建華'),
#   (0.03437827813422763, '男性的本領', '巨星白金系列'),
#   (0.03437827813422763, '彩虹天堂', '劉畊宏'),
#   (0.03437827813422763, 'Get It Started (feat. Shakira)', 'pitbull'),
#   (0.03437827813422763, 'Gobaeghabnida', 'ftisland'),
#   (0.03437827813422763, '清淨法身佛', '齊豫'),
#   (0.03437827813422763, "I'm home| Dear Dad", 'crispy脆樂團'),
#   (0.03437827813422763, '狠不下心', '黃品源'),
#   (0.03437827813422763, '心頭肉', '蔡義德'),
#   (0.03437827813422763, '雨中即景', '滾石金韻民歌百大精選'),
#   (0.03437827813422763, 'SOS', 'abba'),
#   (0.03437827813422763, '深藍色', '拜爾'),
#   (0.03437827813422763, "Nothing's Gonna Change My Love for You", 'westlife'),
#   (0.03437827813422763, 'always on my mind(常駐我心)', '純愛西洋對唱情歌cv'),
#   (0.03437827813422763, '追幸福', '朱海君')],
#  '太極拳Cypher (Tai Chi Fist Cypher)': [(0.5782696594247771,
#    '青春無敵 (Invincible)',
#    'various artists'),
#   (0.5752884311650128, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.5752884311650128, "We Don't Talk Any More", 'various artists'),
#   (0.4839098317331101, 'Remember', 'various artists'),
#   (0.4839098317331101, 'Only Human', 'various artists'),
#   (0.4839098317331101, '胸口發熱 - SeeYa', 'various artists'),
#   (0.4839098317331101, '輕柔的風', 'various artists'),
#   (0.4839098317331101, 'The meaning of the ring', 'various artists'),
#   (0.4839098317331101, '靠近一點點', 'various artists'),
#   (0.4839098317331101, "When I feel I'm into you", 'various artists'),
#   (0.4839098317331101, 'It is your settings', 'various artists'),
#   (0.46548197914542594, 'Angel Grove', 'various artists'),
#   (0.46548197914542594, 'Warm Water (Snakehips Remix)', 'various artists'),
#   (0.4545343223097422, 'Know Better', 'various artists'),
#   (0.42238258445879967,
#    '布魯赫：第一號小提琴協奏曲/第二樂章：慢板 (Violin Concerto No. 1 in G Minor| Op. 26 - Adagio)',
#    'various artists'),
#   (0.42238258445879967,
#    'mozart sonata in d major k448 (2 pianos) - 2nd movement mozart sonata in d major k448 (2 pianos) - 2nd movement',
#    'various artists'),
#   (0.3069813794768775, '越唱越大聲', 'various artists'),
#   (0.3033832884221661, '現在，你在哪裡？', 'various artists'),
#   (0.2737462555376431, 'The Lover', 'various artists'),
#   (0.26426286066359184, '上行之詩 (Pilgrim Song)', 'various artists'),
#   (0.25990407656730347, 'The Prince', 'various artists'),
#   (0.24567712660727986, '你走你的路', 'various artists'),
#   (0.23901021662430327, 'Tell Me If You Wanna Go Home', 'various artists'),
#   (0.22481556761506932, '野子 (Ye Zi)', 'various artists'),
#   (0.20483858888377185, 'I Love You| I Remember You', 'various artists'),
#   (0.20422414938454866, '撕了那封信', 'various artists'),
#   (0.18507735478450002, 'Pandora', 'various artists'),
#   (0.17786767440226578, 'Fine Day', 'various artists'),
#   (0.17478997829751738, 'Flashlight', 'various artists'),
#   (0.16512123244836627, '寫一首歌APRIL 5|1969', 'various artists'),
#   (0.16053491829756228,
#    'Once Again - Mad Clown| Kim Na Young (김나영)',
#    'various artists'),
#   (0.14377373237885782, 'By My Side', 'various artists'),
#   (0.1395569992376465, 'A Gentle Goodbye', 'various artists'),
#   (0.11932901895229193, '在你耳邊說 (Come Out Your Way)', 'eric 周興哲'),
# ...
#   (0.6319386725503428, '胸口發熱 - SeeYa', 'various artists'),
#   (0.6319386725503428, '靠近一點點', 'various artists'),
#   (0.5935771448169458, 'Know Better', 'various artists'),
#   (0.5757462474589096, '青春無敵 (Invincible)', 'various artists'),
#   (0.5515901356566997,
#    '布魯赫：第一號小提琴協奏曲/第二樂章：慢板 (Violin Concerto No. 1 in G Minor| Op. 26 - Adagio)',
#    'various artists'),
#   (0.5515901356566997,
#    'mozart sonata in d major k448 (2 pianos) - 2nd movement mozart sonata in d major k448 (2 pianos) - 2nd movement',
#    'various artists'),
#   (0.46548197914542594, '太極拳Cypher (Tai Chi Fist Cypher)', 'various artists'),
#   (0.4008875057353326, '越唱越大聲', 'various artists'),
#   (0.3976036948289209, 'Pandora', 'various artists'),
#   (0.3585588021063294, '#SELFIE', 'the chainsmokers'),
#   (0.35748570083918946, 'The Lover', 'various artists'),
#   (0.3438906566292281, 'Anywhere You Go (feat. Timmy Trumpet)', 'nervo'),
#   (0.3394091757717154, 'The Prince', 'various artists'),
#   (0.32083017761419086, '你走你的路', 'various artists'),
#   (0.3121238485248111, 'Tell Me If You Wanna Go Home', 'various artists'),
#   (0.3020594060296327, '現在，你在哪裡？', 'various artists'),
#   (0.29358703223387733, '野子 (Ye Zi)', 'various artists'),
#   (0.26749906172125265, 'I Love You| I Remember You', 'various artists'),
#   (0.266696664133853, '撕了那封信', 'various artists'),
#   (0.2631096892082604, '上行之詩 (Pilgrim Song)', 'various artists'),
#   (0.23227769861344125, 'Fine Day', 'various artists'),
#   (0.22825853003407515, 'Flashlight', 'various artists'),
#   (0.22212753455208153, 'Fakin It (feat. Ofelia K)', 'kaskade  felix cartal'),
#   (0.21563209837994612, '寫一首歌APRIL 5|1969', 'various artists'),
#   (0.20964282292757963,
#    'Once Again - Mad Clown| Kim Na Young (김나영)',
#    'various artists'),
#   (0.18775436172004334, 'By My Side', 'various artists'),
#   (0.18224772273688294, 'A Gentle Goodbye', 'various artists'),
#   (0.16903023279036475, 'Rather Be (feat. Jess Glynne)', 'clean bandit'),
#   (0.13613007366515675, 'I Took A Pill In Ibiza', 'mike posner'),
#   (0.1298742318447843, 'Daisy', 'zedd'),
#   (0.12742827398917958, 'Beautiful Now', 'zedd'),
#   (0.1260037409137415,
#    'What We Used To Be - Big Baby Driver',
#    'various artists'),
#   (0.12339947881333574, '閃亮的女孩', '羅百吉 (jerry lo)'),
#   (0.12251433014053588, 'Shine', 'years & years'),
#   (0.12232006473991786, 'I Wanna Know', 'alesso'),
#   (0.11169276036478785,
#    "Don't You Worry Child (feat. John Martin)",
#    'swedish house mafia'),
#   (0.10394573664217133, 'Summer', 'calvin harris'),
#   (0.09572883948445152,
#    'Hey Mama (feat. Nicki Minaj| Bebe Rexha & Afrojack)',
#    'david guetta'),
#   (0.08457655587579485, 'This Is What You Came For', 'calvin harris')],
#  'Fine Day': [(0.3582016827129708, 'ONE FINE DAY', 'jung yong hwa'),
#   (0.30917999522790185, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.30917999522790185, "We Don't Talk Any More", 'various artists'),
#   (0.24147328379444727, 'Only Human', 'various artists'),
#   (0.24147328379444727, 'Remember', 'various artists'),
#   (0.24147328379444727, "When I feel I'm into you", 'various artists'),
#   (0.24147328379444727, '胸口發熱 - SeeYa', 'various artists'),
#   (0.24147328379444727, 'It is your settings', 'various artists'),
#   (0.24147328379444727, '靠近一點點', 'various artists'),
#   (0.24147328379444727, 'The meaning of the ring', 'various artists'),
#   (0.24147328379444727, '輕柔的風', 'various artists'),
#   (0.23227769861344125, 'Warm Water (Snakehips Remix)', 'various artists'),
#   (0.23227769861344125, 'Angel Grove', 'various artists'),
#   (0.22681476632190378, 'Know Better', 'various artists'),
#   (0.22000131190761688, '青春無敵 (Invincible)', 'various artists'),
#   (0.210770897796316,
#    '布魯赫：第一號小提琴協奏曲/第二樂章：慢板 (Violin Concerto No. 1 in G Minor| Op. 26 - Adagio)',
#    'various artists'),
#   (0.210770897796316,
#    'mozart sonata in d major k448 (2 pianos) - 2nd movement mozart sonata in d major k448 (2 pianos) - 2nd movement',
#    'various artists'),
#   (0.20290669115025758, 'Love Has Left Fall Behind', 'yozoh  jae il jung'),
#   (0.17786767440226578, '太極拳Cypher (Tai Chi Fist Cypher)', 'various artists'),
#   (0.15600516240002474, 'To. Us', 'apink'),
#   (0.1531851533178076, '越唱越大聲', 'various artists'),
#   (0.13660067003467272, 'The Lover', 'various artists'),
#   (0.13517355836830433, 'Ready 2 Love', 'henry (super junior-m)'),
#   (0.13203542556595557, '你走你的路', 'various artists'),
#   (0.1296933575734499, 'The Prince', 'various artists'),
#   (0.12845239645385043, 'Tell Me If You Wanna Go Home', 'various artists'),
#   (0.1208236987864053, '野子 (Ye Zi)', 'various artists'),
#   (0.11542144806648946, '現在，你在哪裡？', 'various artists'),
#   (0.10975715504007019, '撕了那封信', 'various artists'),
#   (0.10221542002656689, 'I Love You| I Remember You', 'various artists'),
#   (0.10053817468528754, '上行之詩 (Pilgrim Song)', 'various artists'),
#   (0.09235447119506275, 'Pandora', 'various artists'),
#   (0.08722102190546131, 'Flashlight', 'various artists'),
#   (0.08627704397364301,
#    'Once Again - Mad Clown| Kim Na Young (김나영)',
#    'various artists'),
#   (0.08267685710465893, 'How Deep Is Your Love', 'take that'),
#   (0.08267685710465893, '愛很簡單', 's.h.e'),
#   (0.08267685710465893, '背影', 'k one'),
#   (0.08239627221602717, '寫一首歌APRIL 5|1969', 'various artists'),
#   (0.071743769198834, 'By My Side', 'various artists'),
#   (0.06963959951324108, 'A Gentle Goodbye', 'various artists'),
#   (0.051855962173404935,
#    'What We Used To Be - Big Baby Driver',
#    'various artists'),
#   (0.022129631595953044, '一眼萬年', 's.h.e'),
#   (0.021578185511977575, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.020246881186370268, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.020246881186370268, '癡癡的等', '信 (shin)'),
#   (0.020246881186370268, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.019394947159749043, '無字的情批', '黃乙玲'),
#   (0.019394947159749043, 'Supermassive Black Hole', 'muse')],
#  '我不是你的那首情歌': [(0.5763467279236809,
#    '幸福不是情歌【三立偶像劇[兩個爸爸]片尾曲】',
#    '劉若英 (rene liu)'),
#   (0.5011179622820816, '在樹上唱歌', '郭靜 (claire kuo)'),
#   (0.4728665363968614, '界線', '郭靜 (claire kuo)'),
#   (0.1943216057203986, '又圓了的月亮', '郭采潔 (amber kuo)'),
#   (0.1030913517457087, '愛，不愛', '柯有倫 (alan kuo)'),
#   (0.09336612105893534, '愛很簡單', 's.h.e'),
#   (0.09336612105893534, 'How Deep Is Your Love', 'take that'),
#   (0.09336612105893534, '背影', 'k one'),
#   (0.02499076446461778, '一眼萬年', 's.h.e'),
#   (0.02496674289523784, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.02496674289523784, "We Don't Talk Any More", 'various artists'),
#   (0.024368022095870575, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.022864593867175466, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.022864593867175466, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.022864593867175466, '癡癡的等', '信 (shin)'),
#   (0.021902513567448382, "Baby Don't Cry", 'bigbang'),
#   (0.021902513567448382, 'Supermassive Black Hole', 'muse'),
#   (0.021902513567448382, 'Peligro', 'reik'),
#   (0.021902513567448382, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.021902513567448382, '無字的情批', '黃乙玲'),
#   (0.021902513567448382, 'YOU & I (BOM Solo)', '2ne1'),
#   (0.021902513567448382, '不愛我就離開我 (基地小虎)', '內地華語精選'),
#   (0.021902513567448382, 'Good Day', 'the click five'),
#   (0.021902513567448382, '放我去飛', '黃乙玲'),
#   (0.021902513567448382, 'Love Song', 'bigbang'),
#   (0.021902513567448382, '千年情', '張秀卿'),
#   (0.021902513567448382, '不讓我的眼淚陪我過夜', '內地華語精選'),
#   (0.021902513567448382, 'Rolling In The Deep', 'adele'),
#   (0.021902513567448382, '狼與美女 (Wolf)', 'exo'),
#   (0.02067293728012189, '彩虹天堂', '劉畊宏'),
#   (0.02067293728012189, '你的第一', '霍建華'),
#   (0.02067293728012189, '追幸福', '朱海君'),
#   (0.02067293728012189, '男性的本領', '巨星白金系列'),
#   (0.02067293728012189, '雨中即景', '滾石金韻民歌百大精選'),
#   (0.02067293728012189, '我愛的人', '星光幫'),
#   (0.02067293728012189, 'Loving You(愛著你)', 'all about love'),
#   (0.02067293728012189, '清淨法身佛', '齊豫'),
#   (0.02067293728012189, '孤單不孤單', '我要當歌手'),
#   (0.02067293728012189, '深藍色', '拜爾'),
#   (0.02067293728012189, 'Ma Boy 2 (feat. 효린)', '일렉트로보이즈'),
#   (0.02067293728012189, 'SOS', 'abba'),
#   (0.02067293728012189, 'Get It Started (feat. Shakira)', 'pitbull'),
#   (0.02067293728012189, '狠不下心', '黃品源'),
#   (0.02067293728012189, '心頭肉', '蔡義德'),
#   (0.02067293728012189, 'Hey| Soul Sister', 'train'),
#   (0.02067293728012189, 'Raise Your Glass (乾杯狂歡)', 'p!nk'),
#   (0.02067293728012189, '你別傻了', '周俊偉'),
#   (0.02067293728012189, "Nothing's Gonna Change My Love for You", 'westlife')],
#  '這裡還有我': [(0.4397337258764089, '我不是你該愛的那個人', '曾沛慈 (pets tseng)'),
#   (0.3630533703005828,
#    '粉筆和塗鴉 (Chalk N Doodle) - 衛視中文台戲劇 <長不大的爸爸>插曲',
#    '曾沛慈 (pets tseng)'),
#   (0.12736329643564898, '離心力 (Centrifugal Force)', '楊乃文 (naiwen yang)'),
#   (0.12467889055277213, '跟你住', '孫盛希 (shi shi)'),
#   (0.11855926318875809, '明天的事情', '徐佳瑩 (lala hsu)'),
#   (0.11071231662943488, '千年', '曾靜玟 (jing wen)'),
#   (0.08472955732611351, '愛很簡單', 's.h.e'),
#   (0.08472955732611351, 'How Deep Is Your Love', 'take that'),
#   (0.08472955732611351, '背影', 'k one'),
#   (0.022679065878635295, '一眼萬年', 's.h.e'),
#   (0.022657266355245474, "We Don't Talk Any More", 'various artists'),
#   (0.022657266355245474, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.022113928496534357, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.02074957055979935, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.02074957055979935, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.02074957055979935, '癡癡的等', '信 (shin)'),
#   (0.019876484723272046, 'Good Day', 'the click five'),
#   (0.019876484723272046, 'Supermassive Black Hole', 'muse'),
#   (0.019876484723272046, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.019876484723272046, "Baby Don't Cry", 'bigbang'),
#   (0.019876484723272046, '無字的情批', '黃乙玲'),
#   (0.019876484723272046, '不愛我就離開我 (基地小虎)', '內地華語精選'),
#   (0.019876484723272046, 'Love Song', 'bigbang'),
#   (0.019876484723272046, 'Peligro', 'reik'),
#   (0.019876484723272046, 'YOU & I (BOM Solo)', '2ne1'),
#   (0.019876484723272046, '不讓我的眼淚陪我過夜', '內地華語精選'),
#   (0.019876484723272046, '放我去飛', '黃乙玲'),
#   (0.019876484723272046, 'Rolling In The Deep', 'adele'),
#   (0.019876484723272046, '狼與美女 (Wolf)', 'exo'),
#   (0.019876484723272046, '千年情', '張秀卿'),
#   (0.018760646843940014, 'Loving You(愛著你)', 'all about love'),
#   (0.018760646843940014, '我愛的人', '星光幫'),
#   (0.018760646843940014, '你別傻了', '周俊偉'),
#   (0.018760646843940014, '雨中即景', '滾石金韻民歌百大精選'),
#   (0.018760646843940014, '你的第一', '霍建華'),
#   (0.018760646843940014, '男性的本領', '巨星白金系列'),
#   (0.018760646843940014, 'Ma Boy 2 (feat. 효린)', '일렉트로보이즈'),
#   (0.018760646843940014, '清淨法身佛', '齊豫'),
#   (0.018760646843940014, '追幸福', '朱海君'),
#   (0.018760646843940014, 'SOS', 'abba'),
#   (0.018760646843940014, 'Raise Your Glass (乾杯狂歡)', 'p!nk'),
#   (0.018760646843940014, '感情路', '翁立友'),
#   (0.018760646843940014, 'Get It Started (feat. Shakira)', 'pitbull'),
#   (0.018760646843940014, "Nothing's Gonna Change My Love for You", 'westlife'),
#   (0.018760646843940014, '狠不下心', '黃品源'),
#   (0.018760646843940014, '深藍色', '拜爾'),
#   (0.018760646843940014, 'Gobaeghabnida', 'ftisland'),
#   (0.018760646843940014, '彩虹天堂', '劉畊宏')],
#  '在樹上唱歌': [(0.590561858633317, '界線', '郭靜 (claire kuo)'),
#   (0.5011179622820816, '我不是你的那首情歌', '郭靜 (claire kuo)'),
#   (0.43563814950943835, '一眼萬年', 's.h.e'),
#   (0.3957725891606968, '不能跟情人說的話', '劉若英 (rene liu)'),
#   (0.24268777723474977, '又圓了的月亮', '郭采潔 (amber kuo)'),
#   (0.1985853192082344, '口袋的溫度', '田馥甄 (hebe)'),
#   (0.1936573987912441, '愛旅行的人', '張韶涵 (angela chang)'),
#   (0.18918321353125736, '成全', '劉若英 (rene liu)'),
#   (0.17986980383722537, '幫妳記得', '潘裕文 (peter pan)'),
#   (0.16761353041347757, '最大的缺點', '小樂 (吳思賢) (ben wu)'),
#   (0.1287505365887652, '愛，不愛', '柯有倫 (alan kuo)'),
#   (0.11660471981394813, '愛很簡單', 's.h.e'),
#   (0.11660471981394813, '背影', 'k one'),
#   (0.11660471981394813, 'How Deep Is Your Love', 'take that'),
#   (0.031180904025437998, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.031180904025437998, "We Don't Talk Any More", 'various artists'),
#   (0.030433163086163735, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.02855553525522156, '癡癡的等', '信 (shin)'),
#   (0.02855553525522156, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.02855553525522156, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.02735399552629373, '千年情', '張秀卿'),
#   (0.02735399552629373, 'Love Song', 'bigbang'),
#   (0.02735399552629373, '狼與美女 (Wolf)', 'exo'),
#   (0.02735399552629373, 'YOU & I (BOM Solo)', '2ne1'),
#   (0.02735399552629373, '不讓我的眼淚陪我過夜', '內地華語精選'),
#   (0.02735399552629373, "Baby Don't Cry", 'bigbang'),
#   (0.02735399552629373, 'Good Day', 'the click five'),
#   (0.02735399552629373, 'Peligro', 'reik'),
#   (0.02735399552629373, '放我去飛', '黃乙玲'),
#   (0.02735399552629373, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.02735399552629373, '不愛我就離開我 (基地小虎)', '內地華語精選'),
#   (0.02735399552629373, '無字的情批', '黃乙玲'),
#   (0.02735399552629373, 'Rolling In The Deep', 'adele'),
#   (0.02735399552629373, 'Supermassive Black Hole', 'muse'),
#   (0.02581838071390286, 'Ma Boy 2 (feat. 효린)', '일렉트로보이즈'),
#   (0.02581838071390286, 'SOS', 'abba'),
#   (0.02581838071390286, 'always on my mind(常駐我心)', '純愛西洋對唱情歌cv'),
#   (0.02581838071390286, '感情路', '翁立友'),
#   (0.02581838071390286, 'Gobaeghabnida', 'ftisland'),
#   (0.02581838071390286, 'Loving You(愛著你)', 'all about love'),
#   (0.02581838071390286, '男性的本領', '巨星白金系列'),
#   (0.02581838071390286, '你別傻了', '周俊偉'),
#   (0.02581838071390286, '彩虹天堂', '劉畊宏'),
#   (0.02581838071390286, "Nothing's Gonna Change My Love for You", 'westlife'),
#   (0.02581838071390286, '清淨法身佛', '齊豫'),
#   (0.02581838071390286, '追幸福', '朱海君'),
#   (0.02581838071390286, '我愛的人', '星光幫'),
#   (0.02581838071390286, 'Get It Started (feat. Shakira)', 'pitbull')],
#  '最大的缺點': [(0.5095232059494349, '一起', '小樂 (吳思賢) (ben wu)'),
#   (0.3847540225809497, '一眼萬年', 's.h.e'),
#   (0.1710807375305107, '不能跟情人說的話', '劉若英 (rene liu)'),
#   (0.17103750732436715, '愛旅行的人', '張韶涵 (angela chang)'),
#   (0.16761353041347757, '在樹上唱歌', '郭靜 (claire kuo)'),
#   (0.1588603538169226, '幫妳記得', '潘裕文 (peter pan)'),
#   (0.13868005621138135, '擁抱不算愛情 (Undefined Relationship)', '李佳薇 (jess lee)'),
#   (0.12168032693180805, '這樣的一個麻煩(國)', '陳奕迅 (eason chan)'),
#   (0.10783960468272914, '人在雨中', '張學友 (jacky cheung)'),
#   (0.1029848626683901, 'How Deep Is Your Love', 'take that'),
#   (0.1029848626683901, '背影', 'k one'),
#   (0.1029848626683901, '愛很簡單', 's.h.e'),
#   (0.09903200028549414, '全部都給你', '吳克群 (kenji wu)'),
#   (0.09837422941435482, '靈魂的共鳴', '林俊傑 (jj lin)'),
#   (0.09777468833237403, '不羈 (BOOGIE)', '吳建豪 (vanness wu)'),
#   (0.09486673634834707, '裂縫中的陽光 (Before Sunrise)', '林俊傑 (jj lin)'),
#   (0.09181911412624204, '珍惜', '李碧華'),
#   (0.08646827987378511, '我要快樂 (Desire for happiness)', 'amei (張惠妹)'),
#   (0.0834787830526498, '愛之深責之切', '吳克群 (kenji wu)'),
#   (0.0834787830526498, '牽牽牽手', '吳克群 (kenji wu)'),
#   (0.07545459706030355, '壞脾氣 (Breaking Point)', '吳汶芳 (fang wu)'),
#   (0.0698078452888358, '愛在我身邊', '吳映潔 (emma wu)'),
#   (0.02753886055435527, 'ORIGINAL RESONANCE', 'various artists'),
#   (0.02753886055435527, "We Don't Talk Any More", 'various artists'),
#   (0.026878458487735995, 'Never Gonna Leave This Bed', 'maroon 5'),
#   (0.025220144445041497, '癡癡的等', '信 (shin)'),
#   (0.025220144445041497, 'A.I.N.Y.', 'g.e.m.鄧紫棋'),
#   (0.025220144445041497, 'One Thing (神奇的魔力)', 'one direction'),
#   (0.024158948944793444, '無字的情批', '黃乙玲'),
#   (0.024158948944793444, '千年情', '張秀卿'),
#   (0.024158948944793444, '不愛我就離開我 (基地小虎)', '內地華語精選'),
#   (0.024158948944793444, 'Set Fire To The Rain (Moto Blanco Remix)', 'adele'),
#   (0.024158948944793444, '狼與美女 (Wolf)', 'exo'),
#   (0.024158948944793444, 'Rolling In The Deep', 'adele'),
#   (0.024158948944793444, 'YOU & I (BOM Solo)', '2ne1'),
#   (0.024158948944793444, 'Good Day', 'the click five'),
#   (0.024158948944793444, '放我去飛', '黃乙玲'),
#   (0.024158948944793444, "Baby Don't Cry", 'bigbang'),
#   (0.024158948944793444, 'Peligro', 'reik'),
#   (0.024158948944793444, 'Love Song', 'bigbang'),
#   (0.024158948944793444, 'Supermassive Black Hole', 'muse'),
#   (0.024158948944793444, '不讓我的眼淚陪我過夜', '內地華語精選'),
#   (0.02280269955096142, 'Hey| Soul Sister', 'train'),
#   (0.02280269955096142, '你的第一', '霍建華'),
#   (0.02280269955096142, '你別傻了', '周俊偉'),
#   (0.02280269955096142, 'Get It Started (feat. Shakira)', 'pitbull'),
#   (0.02280269955096142, '狠不下心', '黃品源'),
#   (0.02280269955096142, 'Raise Your Glass (乾杯狂歡)', 'p!nk')]}

# %% [markdown]
# ## `Step-5:` Constructing Content Based Recommendation System.
#
# `Constructor function` will initialize computed similarities dict for every songs to similarity_mat.Also, stores user's playlist history as a list into user_history_list. ( This was experimented before and are provided in markdown section. Scroll above how i come to this step.)
#
# `PrintRecommendedSongs` will print mentioned number of most similar and disinct songs(not already in his/her previous playlist) for user according to user's previous playlist.
#
# `user_songs_history` will return user's playlist history using userID.
#
# `return_most_similar_songs` will return recommended songs for particular songs according to cosine similarities values.
#
# `recommend` will take recommendation dictionary with keys: userID and number_songs. It will recommend mentioned number of distinct and most similar songs for the particular user with that userID

# %%
class ContentBasedRecommender:
    def __init__(self, similarity_matrix):
        self.similarity_mat = similarity_matrix
        self.user_history_list = main_df.groupby(['user_id'])['song_name'].apply(list)
    
    def PrintRecommendedSongs(self, song, recom_song, number_songs, user_play_list):
        print(f"Length of Possible Recommended Songs : {len(recom_song)}\n")
        print(f'The {number_songs} recommended songs are:')
        i=0
        k=0
        temp_recom_list = []
        while(i!=number_songs):
            
            if k < len(recom_song): # Handling index out of range error...
                    if recom_song[k][1] in user_play_list or recom_song[k][1] in temp_recom_list:
                        k = k+1
                    else:
                        if recom_song[k][0] != 0.0:   # Enters if similarity_score less than 0.0
                            print(f"Number {i+1}:")
                            print(f"{recom_song[k][1]} by {recom_song[k][2]} with {recom_song[k][0]} similarity score") 
                            print("--------------------")
                            temp_recom_list.append(recom_song[k][1])

                            # print(temp_recom_list)

                            i=i+1
                            k=k+1
                        else: ## Not Displaying songs with cosine_similarity score of Zero. You can customize this setting yourself.
                            print("Opps!!! No Similar Songs for Recommendations. You can go through most popular songs of this week!!!")
                            break

            else:
                print("Opps !!! There are no more similar songs!!!")
                break
        
                

            
    def user_songs_history(self, userID):
        user_history_values = self.user_history_list[userID]
        user_playlist = []
        print(f"User ID: {userID}\n\n")
        print("Songs History:\n")
        for i in range(len(user_history_values)):
            song  = user_history_values[i]
            print(f"{i+1}. {song}\n")
            user_playlist.append(song)
        return user_playlist
        
        
    def return_most_similar_song(self, song, number_songs):
         recom_song = self.similarity_mat[song][:number_songs]
         return recom_song
        
    
    
    def recommend(self, recommendation):
            # Get playlist of particular user
            user_play_list = self.user_songs_history(recommendation['userID_recom'])
            # Get number of songs to recommend
            recom_song_list = []
            number_songs = recommendation['number_songs']
            
            # Get the number of songs most similars from matrix similarities
            
            for song in user_play_list:
                 recom_song_list.extend(self.return_most_similar_song(song, number_songs))
#           print("I am Correct...")
#           print(recom_song_list)
            recom_song_list = sorted(recom_song_list, reverse=True)
            # print each item
#           print(recom_song_list)
            self.PrintRecommendedSongs(song=song,
                                       recom_song=recom_song_list,
                                       number_songs=number_songs,
                                       user_play_list=user_play_list)

# %% [markdown]
# ## `Step-6:` Making Recommendation of Songs to user
#
# Making Recommendation of songs to Users according to userID and number of songs user requested.

# %%
recommedations = ContentBasedRecommender(similarities)

# %%
recommendation = {
    "userID_recom": main_df['user_id'].iloc[1],
    "number_songs": 50 
}

# %%
recommedations.recommend(recommendation)
# Out:
# User ID: hZyOA+0yqClPLt6uIEndf8fG8szH/95eKMbaxLE5z30=
#
#
# Songs History:
#
# 1. Panda
#
# Length of Possible Recommended Songs : 48
#
# The 50 recommended songs are:
# Number 1:
# Tiimmy Turner by desiigner with 0.6372222477539108 similarity score
# --------------------
# Number 2:
# Know Better by various artists with 0.2015057132188654 similarity score
# --------------------
# Number 3:
# 우리 지금 만나 Let's Meet Now (feat. 장기하와 얼굴들 Kiha & The Faces) by leessang with 0.17767445140893937 similarity score
# --------------------
# Number 4:
# Sometimes by geeks with 0.1593882964940167 similarity score
# --------------------
# Number 5:
# Where'd You Go (feat. Holly Brook & Jonah Matranga) by fort minor with 0.13735827152835292 similarity score
# --------------------
# Number 6:
# Turn Around [5|4|3|2|1] by flo rida with 0.13735827152835292 similarity score
# --------------------
# Number 7:
# Pull Up (feat. Lil Uzi Vert) by wiz khalifa with 0.13735827152835292 similarity score
# --------------------
# Number 8:
# 你不愛我 by 玖壹壹 with 0.12423277761241787 similarity score
# --------------------
# Number 9:
# Same Love (feat. Mary Lambert) by macklemore & ryan lewis with 0.12347165298926878 similarity score
# --------------------
# Number 10:
# 心電感應 by under lover (地下情人) with 0.08657924206912064 similarity score
# --------------------
# Number 11:
# La La La by sam smith with 0.08603402744413446 similarity score
# --------------------
# Number 12:
# Sing For The Moment by eminem with 0.07976388273961801 similarity score
# --------------------
# Number 13:
# Trap Queen by fetty wap with 0.06128570622004471 similarity score
# --------------------
# Number 14:
# Why You Always Hatin? by yg with 0.05607870563074463 similarity score
# --------------------
# Number 15:
# Me| Myself & I by g-eazy with 0.03903227669831226 similarity score
# --------------------
# Opps!!! No Similar Songs for Recommendations. You can go through most popular songs of this week!!!

# %% [markdown]
# ### Further Scope & Enhancements:
#
# 1) If you can display output in dataframe table, it might look beautiful and clear.
#
# 2) Also, you can append listened songs by user from recommended list and make it realistic.
#
# 3) Also , you can encode and decode chinese like language and so on. So, you can improve alot!
#
# As it was for intern. Limiting my features to this much. ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Thank You for Visiting and Exploring my ideas and codes. Glad to share this to you.

# %% [markdown]
# ### `Finally completed my third task successfully`
#
# ## Thanking to `LetsGrowMore` and Respected sir `Aman Kesarwami` for this
#
# ## golden opportunity to improve and enhance myself in the field of
#
# ## DataScience
#
#
# ### Also, i would like to thanks my mate Aman Poddar for coordination.
#
# His linkedin id : https://www.linkedin.com/in/amanpoddar375/
#
# ###  References:
#
# https://github.com/ugis22/music_recommender
# https://towardsdatascience.com/the-abc-of-building-a-music-recommender-system-part-i-230e99da9cad
#
#
# ### Contact  me:
#
# linkedin: https://www.linkedin.com/in/abhishek-thapa-b9a733199/
#
# ### Youtube Channel : `64bitCODING`
#
# Plese do Like and Suscribe and Support me.Thanks every passionate learner in advance!
# Also, Dont forget to reference my contents if you are using anywhere.
#
# <img src="yt-channel.png"/>
#
# Copyright © 2022, Abhishek Thapa Inc. All Rights Reserved
